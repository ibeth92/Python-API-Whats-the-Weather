# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q=seattle&appid={weather_api_key}").json()
response["coord"]["lon"]
# Out:
# -122.33

# %%
# For loop to find i and city, which are 2 of the 3 variables you need 
# The third is the set, which is a group of 50. 
# Everytime I=50, you’ll want set to increment+1.
for i, city in enumerate(cities):
    city_data[i] = response["name"] == city[i], 'cities'

# add subset 
    set_count = 0
    if i % 50 == 0:
        set_count+=1
    
    
    l1 = ["eat","sleep","repeat"] 
  
# printing the tuples in object directly 
for ele in enumerate(l1): 
    print ele 
print 
# changing index and printing separately 
for count,ele in enumerate(l1,100): 
    print count,ele 
    
    
print("Processing Record %s of Set %s | %s" % ([response], set_count, city))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d1ecf5a1af78> in <module>
#       3 # Everytime I=50, you’ll want set to increment+1.
#       4 for i, city in enumerate(cities):
# ----> 5     city_data[i] = response["name"] == city[i], 'cities'
#       6
#       7 # add subset
#
# NameError: name 'city_data' is not defined

# %%
# Out:
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 297.92, 'feels_like': 298.54, 'temp_min': 296.48, 'temp_max': 299.26, 'pressure': 1008, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 277}, 'rain': {'1h': 0.22}, 'clouds': {'all': 4}, 'dt': 1597697009, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1597658723, 'sunset': 1597708475}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# 5106841
# Albany
# {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 279.53, 'feels_like': 277, 'temp_min': 278.15, 'temp_max': 281.15, 'pressure': 997, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 300}, 'clouds': {'all': 40}, 'dt': 1597697151, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1597697988, 'sunset': 1597735777}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# 2163355
# Hobart
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 274.82, 'feels_like': 271.77, 'temp_min': 274.82, 'temp_max': 274.82, 'pressure': 1020, 'humidity': 97}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 6, 'gust': 4.02}, 'clouds': {'all': 98}, 'dt': 1597697226, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1597693182, 'sunset': 1597730250}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# 6201424
# Mataura
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 298.93, 'feels_like': 298.04, 'temp_min': 298.93, 'temp_max': 298.93, 'pressure': 1014, 'humidity': 74, 'sea_level': 1014, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 7.09, 'deg': 96}, 'clouds': {'all': 2}, 'dt': 1597697234, 'sys': {'country': 'PF', 'sunrise': 1597677959, 'sunset': 1597720464}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# 4020109
# Atuona
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 295.04, 'feels_like': 294.51, 'temp_min': 295.04, 'temp_max': 295.04, 'pressure': 1020, 'humidity': 78, 'sea_level': 1020, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 4.67, 'deg': 47}, 'clouds': {'all': 0}, 'dt': 1597697226, 'sys': {'country': 'PF', 'sunrise': 1597677788, 'sunset': 1597718686}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# 4030556
# Rikitea
# {'coord': {'lon': -35.21, 'lat': -5.79}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 299.67, 'feels_like': 298.15, 'temp_min': 299.15, 'temp_max': 300.15, 'pressure': 1011, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 140}, 'clouds': {'all': 20}, 'dt': 1597697493, 'sys': {'type': 1, 'id': 8417, 'country': 'BR', 'sunrise': 1597652820, 'sunset': 1597695776}, 'timezone': -10800, 'id': 3394023, 'name': 'Natal', 'cod': 200}
# 3394023
# Natal
# {'coord': {'lon': -61.35, 'lat': 45.62}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 287.44, 'feels_like': 284.44, 'temp_min': 287.15, 'temp_max': 287.59, 'pressure': 1012, 'humidity': 93}, 'visibility': 4023, 'wind': {'speed': 5.7, 'deg': 70}, 'rain': {'1h': 2.79}, 'clouds': {'all': 90}, 'dt': 1597697305, 'sys': {'type': 1, 'id': 876, 'country': 'CA', 'sunrise': 1597655336, 'sunset': 1597705806}, 'timezone': -10800, 'id': 6111867, 'name': 'Port Hawkesbury', 'cod': 200}
# 6111867
# Port Hawkesbury
# {'coord': {'lon': 140.83, 'lat': 35.73}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 299.56, 'feels_like': 305.51, 'temp_min': 299.26, 'temp_max': 300.15, 'pressure': 1009, 'humidity': 94}, 'visibility': 8000, 'wind': {'speed': 1, 'deg': 330}, 'clouds': {'all': 75}, 'dt': 1597697298, 'sys': {'type': 1, 'id': 7955, 'country': 'JP', 'sunrise': 1597694278, 'sunset': 1597742607}, 'timezone': 32400, 'id': 2112802, 'name': 'Hasaki', 'cod': 200}
# 2112802
# Hasaki
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 301.13, 'feels_like': 300.99, 'temp_min': 300.37, 'temp_max': 302.15, 'pressure': 1017, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 40}, 'clouds': {'all': 20}, 'dt': 1597697227, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1597680955, 'sunset': 1597727205}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# 5848280
# Kapaa
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 275.15, 'feels_like': 271.89, 'temp_min': 275.15, 'temp_max': 275.15, 'pressure': 987, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1597697410, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1597664929, 'sunset': 1597699548}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# 3833367
# Ushuaia
# {'coord': {'lon': 83.59, 'lat': 28.27}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 295.6, 'feels_like': 298.64, 'temp_min': 295.6, 'temp_max': 295.6, 'pressure': 1006, 'humidity': 82, 'sea_level': 1006, 'grnd_level': 883}, 'visibility': 10000, 'wind': {'speed': 0.42, 'deg': 211}, 'rain': {'1h': 0.16}, 'clouds': {'all': 84}, 'dt': 1597697558, 'sys': {'country': 'NP', 'sunrise': 1597708628, 'sunset': 1597755727}, 'timezone': 20700, 'id': 1283711, 'name': 'Bāglung', 'cod': 200}
# 1283711
# Bāglung
# {'coord': {'lon': 150.86, 'lat': -34.58}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 285.55, 'feels_like': 284.37, 'temp_min': 284.26, 'temp_max': 286.48, 'pressure': 1001, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 90, 'gust': 1.79}, 'clouds': {'all': 90}, 'dt': 1597697276, 'sys': {'type': 3, 'id': 2033627, 'country': 'AU', 'sunrise': 1597696397, 'sunset': 1597735674}, 'timezone': 36000, 'id': 6255012, 'name': 'Flinders', 'cod': 200}
# 6255012
# Flinders
# {'coord': {'lon': 37.15, 'lat': 59.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 282.15, 'feels_like': 280.97, 'temp_min': 282.15, 'temp_max': 282.15, 'pressure': 1009, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 320}, 'clouds': {'all': 4}, 'dt': 1597697558, 'sys': {'type': 1, 'id': 8931, 'country': 'RU', 'sunrise': 1597629286, 'sunset': 1597684583}, 'timezone': 10800, 'id': 554535, 'name': 'Kaduy', 'cod': 200}
# 554535
# Kaduy
# {'coord': {'lon': 124.29, 'lat': 8}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 295.93, 'feels_like': 298.63, 'temp_min': 295.93, 'temp_max': 295.93, 'pressure': 1008, 'humidity': 94}, 'visibility': 8184, 'wind': {'speed': 2.68, 'deg': 233, 'gust': 4.02}, 'rain': {'1h': 1.11}, 'clouds': {'all': 76}, 'dt': 1597697559, 'sys': {'type': 3, 'id': 2007154, 'country': 'PH', 'sunrise': 1597700156, 'sunset': 1597744666}, 'timezone': 28800, 'id': 1701054, 'name': 'Marawi', 'cod': 200}
# 1701054
# Marawi
# {'coord': {'lon': 135.87, 'lat': -34.73}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 285.42, 'feels_like': 278.05, 'temp_min': 285.42, 'temp_max': 285.42, 'pressure': 1001, 'humidity': 68, 'sea_level': 1001, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 9.38, 'deg': 292}, 'clouds': {'all': 14}, 'dt': 1597697314, 'sys': {'country': 'AU', 'sunrise': 1597700003, 'sunset': 1597739261}, 'timezone': 34200, 'id': 2063036, 'name': 'Port Lincoln', 'cod': 200}
# 2063036
# Port Lincoln
# {'coord': {'lon': 147.92, 'lat': 70.63}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 277.33, 'feels_like': 271.52, 'temp_min': 277.33, 'temp_max': 277.33, 'pressure': 1011, 'humidity': 86, 'sea_level': 1011, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.92, 'deg': 303}, 'clouds': {'all': 100}, 'dt': 1597697559, 'sys': {'country': 'RU', 'sunrise': 1597684365, 'sunset': 1597749117}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# 2126123
# Chokurdakh
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.15, 'feels_like': 294.8, 'temp_min': 295.15, 'temp_max': 295.15, 'pressure': 1017, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 90, 'gust': 10.8}, 'clouds': {'all': 75}, 'dt': 1597697756, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1597773670, 'sunset': 1597814885}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# 4032243
# Vaini
# {'coord': {'lon': -25.67, 'lat': 37.73}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 297.15, 'feels_like': 294.79, 'temp_min': 297.15, 'temp_max': 297.15, 'pressure': 1014, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 9.3, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1597697559, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1597647626, 'sunset': 1597696392}, 'timezone': 0, 'id': 3372783, 'name': 'Ponta Delgada', 'cod': 200}
# 3372783
# Ponta Delgada
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 283.41, 'feels_like': 278.94, 'temp_min': 283.41, 'temp_max': 283.41, 'pressure': 1010, 'humidity': 92, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 6.08, 'deg': 185}, 'clouds': {'all': 68}, 'dt': 1597697560, 'sys': {'country': 'RU', 'sunrise': 1597697752, 'sunset': 1597768062}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# 1507390
# Dikson
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 274.82, 'feels_like': 271.77, 'temp_min': 274.82, 'temp_max': 274.82, 'pressure': 1020, 'humidity': 97}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 6, 'gust': 4.02}, 'clouds': {'all': 100}, 'dt': 1597697560, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1597693356, 'sunset': 1597730330}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# 2206939
# Bluff
# {'coord': {'lon': -77.03, 'lat': -12.04}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 290.15, 'feels_like': 287.87, 'temp_min': 290.15, 'temp_max': 290.15, 'pressure': 1015, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 180}, 'clouds': {'all': 90}, 'dt': 1597697390, 'sys': {'type': 1, 'id': 8682, 'country': 'PE', 'sunrise': 1597663212, 'sunset': 1597705455}, 'timezone': -18000, 'id': 3936456, 'name': 'Lima', 'cod': 200}
# 3936456
# Lima
# {'coord': {'lon': 100.34, 'lat': 5.41}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 298.75, 'feels_like': 303.2, 'temp_min': 298.15, 'temp_max': 299.82, 'pressure': 1008, 'humidity': 88}, 'visibility': 7000, 'wind': {'speed': 1.5, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1597697560, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1597706051, 'sunset': 1597750265}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# 1735106
# George Town
# {'coord': {'lon': 73.51, 'lat': 4.17}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 306.8, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1008, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 222}, 'clouds': {'all': 75}, 'dt': 1597697757, 'sys': {'type': 1, 'id': 9232, 'country': 'MV', 'sunrise': 1597712560, 'sunset': 1597756633}, 'timezone': 18000, 'id': 1282027, 'name': 'Malé', 'cod': 200}
# 1282027
# Malé
# {'coord': {'lon': -43.46, 'lat': -2.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 300.19, 'feels_like': 301.25, 'temp_min': 300.19, 'temp_max': 300.19, 'pressure': 1007, 'humidity': 64, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.52, 'deg': 48}, 'clouds': {'all': 13}, 'dt': 1597697757, 'sys': {'country': 'BR', 'sunrise': 1597654620, 'sunset': 1597697936}, 'timezone': -10800, 'id': 3398428, 'name': 'Humberto de Campos', 'cod': 200}
# 3398428
# Humberto de Campos
# {'coord': {'lon': 121.9, 'lat': -33.87}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.15, 'feels_like': 273.3, 'temp_min': 282.15, 'temp_max': 282.15, 'pressure': 1005, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 11.3, 'deg': 280, 'gust': 16.5}, 'clouds': {'all': 90}, 'dt': 1597697229, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1597703285, 'sunset': 1597742684}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# 2071860
# Esperance
# {'coord': {'lon': -133.04, 'lat': 69.45}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 283.15, 'feels_like': 280.96, 'temp_min': 283.15, 'temp_max': 283.15, 'pressure': 1016, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 350}, 'clouds': {'all': 75}, 'dt': 1597697261, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1597666156, 'sunset': 1597729392}, 'timezone': -21600, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# 6170031
# Tuktoyaktuk
# {'coord': {'lon': 115.33, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.3, 'feels_like': 276.7, 'temp_min': 280.37, 'temp_max': 284.26, 'pressure': 1008, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 6.49, 'deg': 222}, 'clouds': {'all': 97}, 'dt': 1597697220, 'sys': {'type': 3, 'id': 2011706, 'country': 'AU', 'sunrise': 1597704844, 'sunset': 1597744279}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# 2075265
# Busselton
# {'coord': {'lon': 156.12, 'lat': 50.68}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 284.19, 'feels_like': 283.64, 'temp_min': 284.19, 'temp_max': 284.19, 'pressure': 1012, 'humidity': 89, 'sea_level': 1012, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 0.59, 'deg': 23}, 'clouds': {'all': 91}, 'dt': 1597697232, 'sys': {'country': 'RU', 'sunrise': 1597688877, 'sunset': 1597740669}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# 2121385
# Severo-Kuril'sk
# {'coord': {'lon': -46.05, 'lat': 60.92}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 288.15, 'feels_like': 284.97, 'temp_min': 288.15, 'temp_max': 288.15, 'pressure': 1012, 'humidity': 47}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 330}, 'clouds': {'all': 15}, 'dt': 1597697230, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1597648828, 'sunset': 1597704970}, 'timezone': -7200, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# 3421719
# Narsaq
# {'coord': {'lon': -50.01, 'lat': -24.79}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 289.18, 'feels_like': 288.76, 'temp_min': 289.18, 'temp_max': 289.18, 'pressure': 1013, 'humidity': 95, 'sea_level': 1013, 'grnd_level': 901}, 'visibility': 10000, 'wind': {'speed': 3.03, 'deg': 351}, 'rain': {'1h': 0.74}, 'clouds': {'all': 100}, 'dt': 1597697174, 'sys': {'country': 'BR', 'sunrise': 1597657519, 'sunset': 1597698180}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# 3466704
# Castro
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 298.93, 'feels_like': 299.09, 'temp_min': 295.93, 'temp_max': 301.15, 'pressure': 1016, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1597697250, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1597680095, 'sunset': 1597726035}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# 5855927
# Hilo
# {'coord': {'lon': -88.56, 'lat': 30.37}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 307.24, 'feels_like': 311.09, 'temp_min': 306.48, 'temp_max': 308.15, 'pressure': 1014, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1597697561, 'sys': {'type': 1, 'id': 5398, 'country': 'US', 'sunrise': 1597663365, 'sunset': 1597710835}, 'timezone': -18000, 'id': 4440397, 'name': 'Pascagoula', 'cod': 200}
# 4440397
# Pascagoula
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 279.23, 'feels_like': 277.74, 'temp_min': 278.15, 'temp_max': 280.93, 'pressure': 996, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 331, 'gust': 1.34}, 'clouds': {'all': 70}, 'dt': 1597697240, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1597698043, 'sunset': 1597735852}, 'timezone': 36000, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# 2155415
# New Norfolk
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 20.23, 'lat': 30.76}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 299.55, 'feels_like': 297.62, 'temp_min': 299.55, 'temp_max': 299.55, 'pressure': 1013, 'humidity': 59, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 6.58, 'deg': 5}, 'clouds': {'all': 0}, 'dt': 1597697286, 'sys': {'country': 'LY', 'sunrise': 1597637214, 'sunset': 1597684775}, 'timezone': 7200, 'id': 89113, 'name': 'Ajdabiya', 'cod': 200}
# 89113
# Ajdabiya
# {'coord': {'lon': -70.4, 'lat': -23.65}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 288.15, 'feels_like': 283.64, 'temp_min': 288.15, 'temp_max': 288.15, 'pressure': 1017, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 200}, 'clouds': {'all': 20}, 'dt': 1597697044, 'sys': {'type': 1, 'id': 8488, 'country': 'CL', 'sunrise': 1597662334, 'sunset': 1597703151}, 'timezone': -14400, 'id': 3899539, 'name': 'Antofagasta', 'cod': 200}
# 3899539
# Antofagasta
# {'coord': {'lon': 113.63, 'lat': -24.87}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 286.15, 'feels_like': 284.91, 'temp_min': 286.15, 'temp_max': 286.15, 'pressure': 1018, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 160}, 'clouds': {'all': 17}, 'dt': 1597697253, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1597704623, 'sunset': 1597745315}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# 2074865
# Carnarvon
# {'coord': {'lon': 78.23, 'lat': 26.71}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 302.7, 'feels_like': 311.13, 'temp_min': 302.15, 'temp_max': 303.15, 'pressure': 1001, 'humidity': 94}, 'visibility': 6000, 'wind': {'speed': 0.5, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1597697562, 'sys': {'type': 1, 'id': 9166, 'country': 'IN', 'sunrise': 1597710029, 'sunset': 1597756898}, 'timezone': 19800, 'id': 1278868, 'name': 'Ambāh', 'cod': 200}
# 1278868
# Ambāh
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 170.31, 'lat': 69.7}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 276.41, 'feels_like': 269.73, 'temp_min': 276.41, 'temp_max': 276.41, 'pressure': 1009, 'humidity': 86, 'sea_level': 1009, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 6.95, 'deg': 184}, 'rain': {'1h': 0.24}, 'clouds': {'all': 100}, 'dt': 1597697240, 'sys': {'country': 'RU', 'sunrise': 1597679633, 'sunset': 1597743103}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# 2122090
# Pevek
# {'coord': {'lon': 167.55, 'lat': -13.88}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 299.42, 'feels_like': 303.49, 'temp_min': 299.42, 'temp_max': 299.42, 'pressure': 1010, 'humidity': 83, 'sea_level': 1010, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 68}, 'rain': {'1h': 0.68}, 'clouds': {'all': 43}, 'dt': 1597697563, 'sys': {'country': 'VU', 'sunrise': 1597691010, 'sunset': 1597733050}, 'timezone': 39600, 'id': 2134814, 'name': 'Sola', 'cod': 200}
# 2134814
# Sola
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -27.07, 'lat': 38.73}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 297.15, 'feels_like': 294.99, 'temp_min': 297.15, 'temp_max': 297.15, 'pressure': 1010, 'humidity': 94}, 'visibility': 3500, 'wind': {'speed': 10.55, 'deg': 231}, 'clouds': {'all': 75}, 'dt': 1597697272, 'sys': {'type': 1, 'id': 6895, 'country': 'PT', 'sunrise': 1597647865, 'sunset': 1597696825}, 'timezone': 0, 'id': 3372760, 'name': 'Praia da Vitória', 'cod': 200}
# 3372760
# Praia da Vitória
# {'coord': {'lon': 179.32, 'lat': 63.05}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 284.02, 'feels_like': 278.69, 'temp_min': 284.02, 'temp_max': 284.02, 'pressure': 1007, 'humidity': 85, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 7.11, 'deg': 18}, 'rain': {'1h': 0.36}, 'clouds': {'all': 100}, 'dt': 1597697276, 'sys': {'country': 'RU', 'sunrise': 1597680549, 'sunset': 1597737862}, 'timezone': 43200, 'id': 2126710, 'name': 'Beringovskiy', 'cod': 200}
# 2126710
# Beringovskiy
# {'coord': {'lon': -57.56, 'lat': -38}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 288.15, 'feels_like': 280.88, 'temp_min': 288.15, 'temp_max': 288.15, 'pressure': 1006, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.8, 'deg': 320, 'gust': 14.9}, 'clouds': {'all': 0}, 'dt': 1597697239, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1597660336, 'sunset': 1597698987}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# 3430863
# Mar del Plata
# {'coord': {'lon': 44.32, 'lat': 15.17}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 293.01, 'feels_like': 291.51, 'temp_min': 293.01, 'temp_max': 293.01, 'pressure': 1007, 'humidity': 47, 'sea_level': 1007, 'grnd_level': 759}, 'visibility': 10000, 'wind': {'speed': 1.55, 'deg': 18}, 'clouds': {'all': 88}, 'dt': 1597697563, 'sys': {'country': 'YE', 'sunrise': 1597632518, 'sunset': 1597677909}, 'timezone': 10800, 'id': 70979, 'name': 'Sayyan', 'cod': 200}
# 70979
# Sayyan
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -40.29, 'lat': -20.33}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.72, 'feels_like': 298.79, 'temp_min': 298.15, 'temp_max': 299.82, 'pressure': 1015, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 50}, 'clouds': {'all': 75}, 'dt': 1597697103, 'sys': {'type': 1, 'id': 8474, 'country': 'BR', 'sunrise': 1597654898, 'sunset': 1597696136}, 'timezone': -10800, 'id': 3445026, 'name': 'Vila Velha', 'cod': 200}
# 3445026
# Vila Velha
# {'coord': {'lon': 59.53, 'lat': 22.57}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 304.17, 'feels_like': 305.33, 'temp_min': 304.17, 'temp_max': 304.17, 'pressure': 997, 'humidity': 59, 'sea_level': 997, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 198}, 'clouds': {'all': 80}, 'dt': 1597697253, 'sys': {'country': 'OM', 'sunrise': 1597714807, 'sunset': 1597761096}, 'timezone': 14400, 'id': 286245, 'name': 'Sur', 'cod': 200}
# 286245
# Sur
# {'coord': {'lon': 18.27, 'lat': -1.95}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 296.15, 'feels_like': 298.06, 'temp_min': 296.15, 'temp_max': 296.15, 'pressure': 1010, 'humidity': 81, 'sea_level': 1010, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 2.26, 'deg': 315}, 'clouds': {'all': 64}, 'dt': 1597697564, 'sys': {'country': 'CD', 'sunrise': 1597639770, 'sunset': 1597683159}, 'timezone': 3600, 'id': 2315417, 'name': 'Inongo', 'cod': 200}
# 2315417
# Inongo
# {'coord': {'lon': -73.82, 'lat': -41.87}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 282.85, 'feels_like': 277.9, 'temp_min': 282.15, 'temp_max': 283.71, 'pressure': 1013, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 260}, 'clouds': {'all': 75}, 'dt': 1597697280, 'sys': {'type': 1, 'id': 8512, 'country': 'CL', 'sunrise': 1597664597, 'sunset': 1597702530}, 'timezone': -14400, 'id': 3899695, 'name': 'Ancud', 'cod': 200}
# 3899695
# Ancud
# {'coord': {'lon': 132.75, 'lat': -5.67}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 298.66, 'feels_like': 297.56, 'temp_min': 298.66, 'temp_max': 298.66, 'pressure': 1009, 'humidity': 78, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.83, 'deg': 127}, 'clouds': {'all': 31}, 'dt': 1597697296, 'sys': {'country': 'ID', 'sunrise': 1597698892, 'sunset': 1597741870}, 'timezone': 32400, 'id': 1623197, 'name': 'Tual', 'cod': 200}
# 1623197
# Tual
# {'coord': {'lon': 119.64, 'lat': 41.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 295.34, 'feels_like': 298.65, 'temp_min': 295.34, 'temp_max': 295.34, 'pressure': 1008, 'humidity': 93, 'sea_level': 1008, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 1.25, 'deg': 199}, 'clouds': {'all': 3}, 'dt': 1597697564, 'sys': {'country': 'CN', 'sunrise': 1597698816, 'sunset': 1597748238}, 'timezone': 28800, 'id': 2033423, 'name': 'Yebaishou', 'cod': 200}
# 2033423
# Yebaishou
# {'coord': {'lon': 20.74, 'lat': -8.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.26, 'feels_like': 293.09, 'temp_min': 295.26, 'temp_max': 295.26, 'pressure': 1010, 'humidity': 27, 'sea_level': 1010, 'grnd_level': 906}, 'visibility': 10000, 'wind': {'speed': 0.76, 'deg': 198}, 'clouds': {'all': 57}, 'dt': 1597697565, 'sys': {'country': 'AO', 'sunrise': 1597639546, 'sunset': 1597682198}, 'timezone': 3600, 'id': 145724, 'name': 'Lucapa', 'cod': 200}
# 145724
# Lucapa
# {'coord': {'lon': 18.97, 'lat': -22.45}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 284.02, 'feels_like': 277.31, 'temp_min': 284.02, 'temp_max': 284.02, 'pressure': 1019, 'humidity': 35, 'sea_level': 1019, 'grnd_level': 859}, 'visibility': 10000, 'wind': {'speed': 6.01, 'deg': 219}, 'clouds': {'all': 0}, 'dt': 1597697565, 'sys': {'country': 'NA', 'sunrise': 1597640819, 'sunset': 1597681775}, 'timezone': 7200, 'id': 3357247, 'name': 'Gobabis', 'cod': 200}
# 3357247
# Gobabis
# {'coord': {'lon': -97.07, 'lat': 15.85}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 303.15, 'feels_like': 306.33, 'temp_min': 303.15, 'temp_max': 303.15, 'pressure': 1014, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1597697565, 'sys': {'type': 1, 'id': 7157, 'country': 'MX', 'sunrise': 1597666414, 'sunset': 1597711871}, 'timezone': -18000, 'id': 3520994, 'name': 'Puerto Escondido', 'cod': 200}
# 3520994
# Puerto Escondido
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 294.95, 'feels_like': 292.53, 'temp_min': 294.26, 'temp_max': 296.15, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 6.7, 'deg': 120}, 'clouds': {'all': 40}, 'dt': 1597697245, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1597665767, 'sunset': 1597709293}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# 3652764
# Puerto Ayora
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 282.37, 'feels_like': 276.02, 'temp_min': 282.04, 'temp_max': 283.15, 'pressure': 1020, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 200}, 'clouds': {'all': 40}, 'dt': 1597697384, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1597641773, 'sunset': 1597681084}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# 3369157
# Cape Town
# {'coord': {'lon': 73.08, 'lat': -0.6}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 301.94, 'feels_like': 305.26, 'temp_min': 301.94, 'temp_max': 301.94, 'pressure': 1007, 'humidity': 72, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 2.93, 'deg': 104}, 'clouds': {'all': 40}, 'dt': 1597697246, 'sys': {'country': 'MV', 'sunrise': 1597712928, 'sunset': 1597756471}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# 1282256
# Hithadhoo
# {'coord': {'lon': -151.75, 'lat': -16.52}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 299.24, 'feels_like': 299.59, 'temp_min': 299.24, 'temp_max': 299.24, 'pressure': 1016, 'humidity': 71, 'sea_level': 1016, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 5.06, 'deg': 97}, 'clouds': {'all': 21}, 'dt': 1597697565, 'sys': {'country': 'PF', 'sunrise': 1597681402, 'sunset': 1597723125}, 'timezone': -36000, 'id': 4033077, 'name': 'Vaitape', 'cod': 200}
# 4033077
# Vaitape
# {'coord': {'lon': 150.47, 'lat': -35.35}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 281.87, 'feels_like': 278.7, 'temp_min': 278.71, 'temp_max': 284.15, 'pressure': 1005, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 350}, 'clouds': {'all': 90}, 'dt': 1597697566, 'sys': {'type': 1, 'id': 9594, 'country': 'AU', 'sunrise': 1597696552, 'sunset': 1597735705}, 'timezone': 36000, 'id': 2145554, 'name': 'Ulladulla', 'cod': 200}
# 2145554
# Ulladulla
# {'coord': {'lon': 24.73, 'lat': -34}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 285.93, 'feels_like': 282.23, 'temp_min': 285.93, 'temp_max': 285.93, 'pressure': 1010, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 4.02, 'deg': 283, 'gust': 7.6}, 'rain': {'1h': 1.56}, 'clouds': {'all': 100}, 'dt': 1597697237, 'sys': {'type': 3, 'id': 2035063, 'country': 'ZA', 'sunrise': 1597640266, 'sunset': 1597679563}, 'timezone': 7200, 'id': 986717, 'name': 'Kruisfontein', 'cod': 200}
# 986717
# Kruisfontein
# {'coord': {'lon': -57.63, 'lat': -32.68}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 293.71, 'feels_like': 291.31, 'temp_min': 293.71, 'temp_max': 293.71, 'pressure': 1013, 'humidity': 33}, 'visibility': 10000, 'wind': {'speed': 1.47, 'deg': 348}, 'clouds': {'all': 0}, 'dt': 1597697551, 'sys': {'type': 3, 'id': 2019376, 'country': 'UY', 'sunrise': 1597659913, 'sunset': 1597699443}, 'timezone': -10800, 'id': 3439525, 'name': 'Young', 'cod': 200}
# 3439525
# Young
# {'coord': {'lon': 140.3, 'lat': 35.13}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 299.4, 'feels_like': 305.92, 'temp_min': 299.15, 'temp_max': 299.82, 'pressure': 1009, 'humidity': 100}, 'visibility': 5000, 'wind': {'speed': 1, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1597697278, 'sys': {'type': 1, 'id': 8052, 'country': 'JP', 'sunrise': 1597694458, 'sunset': 1597742680}, 'timezone': 32400, 'id': 2112309, 'name': 'Katsuura', 'cod': 200}
# 2112309
# Katsuura
# {'coord': {'lon': 169.27, 'lat': -19.55}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 299.15, 'feels_like': 300.76, 'temp_min': 299.15, 'temp_max': 299.15, 'pressure': 1007, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 20}, 'clouds': {'all': 90}, 'dt': 1597697274, 'sys': {'type': 1, 'id': 7317, 'country': 'VU', 'sunrise': 1597690938, 'sunset': 1597732297}, 'timezone': 39600, 'id': 2136825, 'name': 'Isangel', 'cod': 200}
# 2136825
# Isangel
# {'coord': {'lon': -45.24, 'lat': 60.14}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 282.98, 'feels_like': 278.79, 'temp_min': 282.98, 'temp_max': 282.98, 'pressure': 1013, 'humidity': 58, 'sea_level': 1013, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 3.59, 'deg': 319}, 'clouds': {'all': 42}, 'dt': 1597697256, 'sys': {'country': 'GL', 'sunrise': 1597648848, 'sunset': 1597704562}, 'timezone': -7200, 'id': 3421765, 'name': 'Nanortalik', 'cod': 200}
# 3421765
# Nanortalik
# {'coord': {'lon': -37.64, 'lat': 65.61}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 284.15, 'feels_like': 282.44, 'temp_min': 284.15, 'temp_max': 284.15, 'pressure': 1016, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 250}, 'clouds': {'all': 40}, 'dt': 1597697239, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1597645192, 'sunset': 1597704571}, 'timezone': -7200, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# 3424607
# Tasiilaq
# {'coord': {'lon': 139.5, 'lat': -20.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 283.15, 'feels_like': 278.5, 'temp_min': 283.15, 'temp_max': 283.15, 'pressure': 1012, 'humidity': 32}, 'visibility': 10000, 'wind': {'speed': 2.78, 'deg': 339}, 'clouds': {'all': 0}, 'dt': 1597697309, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1597698152, 'sunset': 1597739370}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# 2065594
# Mount Isa
# {'coord': {'lon': 108.21, 'lat': -7.38}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 295.66, 'feels_like': 299.27, 'temp_min': 295.66, 'temp_max': 295.66, 'pressure': 1010, 'humidity': 92, 'sea_level': 1010, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 0.93, 'deg': 111}, 'rain': {'1h': 0.24}, 'clouds': {'all': 96}, 'dt': 1597697567, 'sys': {'country': 'ID', 'sunrise': 1597704876, 'sunset': 1597747663}, 'timezone': 25200, 'id': 1640902, 'name': 'Kawalu', 'cod': 200}
# 1640902
# Kawalu
# {'coord': {'lon': 55.77, 'lat': -21.36}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 290.02, 'feels_like': 288.41, 'temp_min': 285.93, 'temp_max': 292.15, 'pressure': 1021, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 10}, 'clouds': {'all': 39}, 'dt': 1597697257, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1597718276, 'sunset': 1597759430}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# 935215
# Saint-Philippe
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -79.24, 'lat': 42.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.43, 'feels_like': 294.83, 'temp_min': 295.93, 'temp_max': 297.04, 'pressure': 1014, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 290}, 'clouds': {'all': 1}, 'dt': 1597697049, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1597660044, 'sunset': 1597709684}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# 5122534
# Jamestown
# {'coord': {'lon': 18.3, 'lat': 57.64}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 289, 'feels_like': 288.1, 'temp_min': 286.48, 'temp_max': 290.15, 'pressure': 1013, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 100}, 'clouds': {'all': 96}, 'dt': 1597697567, 'sys': {'type': 1, 'id': 1796, 'country': 'SE', 'sunrise': 1597634190, 'sunset': 1597688725}, 'timezone': 7200, 'id': 2662689, 'name': 'Visby', 'cod': 200}
# 2662689
# Visby
# {'coord': {'lon': 114.16, 'lat': 22.29}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 299.82, 'feels_like': 303.42, 'temp_min': 299.82, 'temp_max': 299.82, 'pressure': 1007, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 2.79, 'deg': 26}, 'clouds': {'all': 100}, 'dt': 1597697034, 'sys': {'type': 3, 'id': 47808, 'country': 'HK', 'sunrise': 1597701711, 'sunset': 1597747973}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# 1819729
# Hong Kong
# {'coord': {'lon': -53.46, 'lat': 68.31}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 281.67, 'feels_like': 279.57, 'temp_min': 281.67, 'temp_max': 281.67, 'pressure': 1016, 'humidity': 68, 'sea_level': 1016, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 0.84, 'deg': 42}, 'clouds': {'all': 53}, 'dt': 1597697567, 'sys': {'country': 'GL', 'sunrise': 1597647686, 'sunset': 1597709669}, 'timezone': -7200, 'id': 3422683, 'name': 'Kangaatsiaq', 'cod': 200}
# 3422683
# Kangaatsiaq
# {'coord': {'lon': 167.68, 'lat': -46.13}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 274.82, 'feels_like': 271.77, 'temp_min': 274.82, 'temp_max': 274.82, 'pressure': 1020, 'humidity': 97}, 'visibility': 10000, 'wind': {'speed': 1.79, 'deg': 6, 'gust': 4.02}, 'clouds': {'all': 89}, 'dt': 1597697242, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1597693458, 'sunset': 1597730540}, 'timezone': 43200, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# 2180815
# Tuatapere
# {'coord': {'lon': 166.1, 'lat': 60.47}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 284.31, 'feels_like': 279.45, 'temp_min': 284.31, 'temp_max': 284.31, 'pressure': 1012, 'humidity': 56, 'sea_level': 1012, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 4.73, 'deg': 359}, 'clouds': {'all': 13}, 'dt': 1597697568, 'sys': {'country': 'RU', 'sunrise': 1597684498, 'sunset': 1597740258}, 'timezone': 43200, 'id': 2120591, 'name': 'Tilichiki', 'cod': 200}
# 2120591
# Tilichiki
# {'coord': {'lon': 172.79, 'lat': 3.07}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 300.75, 'feels_like': 301.8, 'temp_min': 300.75, 'temp_max': 300.75, 'pressure': 1011, 'humidity': 62, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 3.55, 'deg': 63}, 'clouds': {'all': 0}, 'dt': 1597697234, 'sys': {'country': 'KI', 'sunrise': 1597688796, 'sunset': 1597732749}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# 2110227
# Butaritari
# {'coord': {'lon': -81.25, 'lat': 19.28}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 304, 'feels_like': 309.79, 'temp_min': 303.15, 'temp_max': 304.82, 'pressure': 1013, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 70}, 'clouds': {'all': 40}, 'dt': 1597697568, 'sys': {'type': 1, 'id': 7265, 'country': 'KY', 'sunrise': 1597662399, 'sunset': 1597708293}, 'timezone': -18000, 'id': 3580733, 'name': 'Bodden Town', 'cod': 200}
# 3580733
# Bodden Town
# {'coord': {'lon': -44.87, 'lat': -1.83}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 299.05, 'feels_like': 301.62, 'temp_min': 299.05, 'temp_max': 299.05, 'pressure': 1008, 'humidity': 74, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 2.23, 'deg': 49}, 'clouds': {'all': 38}, 'dt': 1597697568, 'sys': {'country': 'BR', 'sunrise': 1597654915, 'sunset': 1597698318}, 'timezone': -10800, 'id': 3401148, 'name': 'Cururupu', 'cod': 200}
# 3401148
# Cururupu
# {'coord': {'lon': 137.77, 'lat': -32.5}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 278.11, 'feels_like': 274.08, 'temp_min': 277.04, 'temp_max': 281.15, 'pressure': 1005, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 340}, 'clouds': {'all': 90}, 'dt': 1597697568, 'sys': {'type': 1, 'id': 9613, 'country': 'AU', 'sunrise': 1597699373, 'sunset': 1597738979}, 'timezone': 34200, 'id': 2063056, 'name': 'Port Augusta', 'cod': 200}
# 2063056
# Port Augusta
# {'coord': {'lon': 79.17, 'lat': 52.27}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 291.11, 'feels_like': 288.67, 'temp_min': 291.11, 'temp_max': 291.11, 'pressure': 999, 'humidity': 60, 'sea_level': 999, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 3.58, 'deg': 15}, 'clouds': {'all': 98}, 'dt': 1597697295, 'sys': {'country': 'RU', 'sunrise': 1597707113, 'sunset': 1597759364}, 'timezone': 25200, 'id': 1503153, 'name': 'Klyuchi', 'cod': 200}
# 1503153
# Klyuchi
# {'coord': {'lon': 178.42, 'lat': 69.38}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 278.43, 'feels_like': 271.8, 'temp_min': 278.43, 'temp_max': 278.43, 'pressure': 1011, 'humidity': 78, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.03, 'deg': 298}, 'clouds': {'all': 100}, 'dt': 1597697230, 'sys': {'country': 'RU', 'sunrise': 1597677888, 'sunset': 1597740956}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# 2123814
# Leningradskiy
# {'coord': {'lon': -1.89, 'lat': 12.66}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 307.2, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1010, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 0}, 'clouds': {'all': 20}, 'dt': 1597697569, 'sys': {'type': 1, 'id': 1122, 'country': 'BF', 'sunrise': 1597643763, 'sunset': 1597688842}, 'timezone': 0, 'id': 2361845, 'name': 'Boussé', 'cod': 200}
# 2361845
# Boussé
# {'coord': {'lon': 86.32, 'lat': 55.72}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 290.15, 'feels_like': 291.38, 'temp_min': 290.15, 'temp_max': 290.15, 'pressure': 1003, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 90}, 'clouds': {'all': 98}, 'dt': 1597697569, 'sys': {'type': 1, 'id': 8950, 'country': 'RU', 'sunrise': 1597704772, 'sunset': 1597758273}, 'timezone': 25200, 'id': 1510817, 'name': 'Barzas', 'cod': 200}
# 1510817
# Barzas
# {'coord': {'lon': -97.86, 'lat': 55.74}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 290.15, 'feels_like': 288.35, 'temp_min': 290.15, 'temp_max': 290.15, 'pressure': 1019, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 130}, 'clouds': {'all': 90}, 'dt': 1597697149, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1597662514, 'sunset': 1597716149}, 'timezone': -18000, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# 6165406
# Thompson
# {'coord': {'lon': 49.18, 'lat': 11.28}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 307.89, 'feels_like': 305.14, 'temp_min': 307.89, 'temp_max': 307.89, 'pressure': 1004, 'humidity': 39, 'sea_level': 1004, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 8.37, 'deg': 168}, 'clouds': {'all': 99}, 'dt': 1597697569, 'sys': {'country': 'SO', 'sunrise': 1597631589, 'sunset': 1597676506}, 'timezone': 10800, 'id': 64013, 'name': 'Bosaso', 'cod': 200}
# 64013
# Bosaso
# {'coord': {'lon': 75.98, 'lat': 39.45}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 300.15, 'feels_like': 300.02, 'temp_min': 300.15, 'temp_max': 300.15, 'pressure': 1010, 'humidity': 39}, 'visibility': 10000, 'wind': {'speed': 1, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1597697569, 'sys': {'type': 1, 'id': 9676, 'country': 'CN', 'sunrise': 1597709501, 'sunset': 1597758506}, 'timezone': 28800, 'id': 1280849, 'name': 'Kashgar', 'cod': 200}
# 1280849
# Kashgar
# {'coord': {'lon': -58.08, 'lat': -32.32}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 293.71, 'feels_like': 291.31, 'temp_min': 293.71, 'temp_max': 293.71, 'pressure': 1013, 'humidity': 33}, 'visibility': 10000, 'wind': {'speed': 1.47, 'deg': 2}, 'clouds': {'all': 0}, 'dt': 1597697569, 'sys': {'type': 3, 'id': 2019376, 'country': 'UY', 'sunrise': 1597659993, 'sunset': 1597699579}, 'timezone': -10800, 'id': 3441243, 'name': 'Paysandu', 'cod': 200}
# 3441243
# Paysandu
# {'coord': {'lon': -75.46, 'lat': 43.21}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 298.15, 'feels_like': 294.01, 'temp_min': 295.93, 'temp_max': 300.15, 'pressure': 1011, 'humidity': 47}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 290, 'gust': 9.3}, 'clouds': {'all': 40}, 'dt': 1597697369, 'sys': {'type': 1, 'id': 5681, 'country': 'US', 'sunrise': 1597659012, 'sunset': 1597708901}, 'timezone': -14400, 'id': 5134295, 'name': 'Rome', 'cod': 200}
# 5134295
# Rome
# ...
# 5509851
# Pahrump
# {'coord': {'lon': -151.26, 'lat': 60.55}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 289.54, 'feels_like': 286.23, 'temp_min': 288.15, 'temp_max': 291.15, 'pressure': 1008, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 210}, 'clouds': {'all': 40}, 'dt': 1597697272, 'sys': {'type': 1, 'id': 7680, 'country': 'US', 'sunrise': 1597674226, 'sunset': 1597730067}, 'timezone': -28800, 'id': 5866063, 'name': 'Kenai', 'cod': 200}
# 5866063
# Kenai
# {'coord': {'lon': 12.92, 'lat': 18.69}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 309.14, 'feels_like': 306.42, 'temp_min': 309.14, 'temp_max': 309.14, 'pressure': 1007, 'humidity': 18, 'sea_level': 1007, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 3.19, 'deg': 76}, 'clouds': {'all': 27}, 'dt': 1597697641, 'sys': {'country': 'NE', 'sunrise': 1597639832, 'sunset': 1597685665}, 'timezone': 3600, 'id': 2446796, 'name': 'Bilma', 'cod': 200}
# 2446796
# Bilma
# {'coord': {'lon': 15.03, 'lat': 12.08}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 300.15, 'feels_like': 301.96, 'temp_min': 300.15, 'temp_max': 300.15, 'pressure': 1009, 'humidity': 75, 'sea_level': 1009, 'grnd_level': 975}, 'visibility': 10000, 'wind': {'speed': 4.26, 'deg': 162}, 'rain': {'1h': 0.51}, 'clouds': {'all': 91}, 'dt': 1597697641, 'sys': {'country': 'CM', 'sunrise': 1597639737, 'sunset': 1597684747}, 'timezone': 3600, 'id': 2229798, 'name': 'Kousséri', 'cod': 200}
# 2229798
# Kousséri
# {'coord': {'lon': 94.73, 'lat': 16.78}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 298.67, 'feels_like': 302.88, 'temp_min': 298.67, 'temp_max': 298.67, 'pressure': 1005, 'humidity': 91, 'sea_level': 1005, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 201}, 'rain': {'1h': 0.32}, 'clouds': {'all': 100}, 'dt': 1597697642, 'sys': {'country': 'MM', 'sunrise': 1597706729, 'sunset': 1597752279}, 'timezone': 23400, 'id': 1328421, 'name': 'Pathein', 'cod': 200}
# 1328421
# Pathein
# {'coord': {'lon': -77.02, 'lat': 39.55}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 298.37, 'feels_like': 299.98, 'temp_min': 295.93, 'temp_max': 299.82, 'pressure': 1011, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 267, 'gust': 11.18}, 'rain': {'1h': 0.25}, 'clouds': {'all': 0}, 'dt': 1597697642, 'sys': {'type': 3, 'id': 2018638, 'country': 'US', 'sunrise': 1597659779, 'sunset': 1597708883}, 'timezone': -14400, 'id': 4350461, 'name': 'Carroll', 'cod': 200}
# 4350461
# Carroll
# {'coord': {'lon': -10.8, 'lat': 6.3}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 298.15, 'feels_like': 300.13, 'temp_min': 298.15, 'temp_max': 298.15, 'pressure': 1011, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 3.82, 'deg': 215}, 'clouds': {'all': 75}, 'dt': 1597697642, 'sys': {'type': 1, 'id': 2389, 'country': 'LR', 'sunrise': 1597646277, 'sunset': 1597690604}, 'timezone': 0, 'id': 2274895, 'name': 'Monrovia', 'cod': 200}
# 2274895
# Monrovia
# {'coord': {'lon': 144.22, 'lat': -37.07}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 279.8, 'feels_like': 276.39, 'temp_min': 278.71, 'temp_max': 280.37, 'pressure': 1000, 'humidity': 61}, 'visibility': 2379, 'wind': {'speed': 1.97, 'deg': 351}, 'clouds': {'all': 93}, 'dt': 1597697642, 'sys': {'type': 3, 'id': 2007489, 'country': 'AU', 'sunrise': 1597698195, 'sunset': 1597737062}, 'timezone': 36000, 'id': 2172106, 'name': 'Castlemaine', 'cod': 200}
# 2172106
# Castlemaine
# {'coord': {'lon': 140.77, 'lat': -37.83}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 282.15, 'feels_like': 278.45, 'temp_min': 282.15, 'temp_max': 282.15, 'pressure': 999, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 4.6, 'deg': 350}, 'clouds': {'all': 90}, 'dt': 1597697316, 'sys': {'type': 1, 'id': 9560, 'country': 'AU', 'sunrise': 1597699087, 'sunset': 1597737825}, 'timezone': 34200, 'id': 2156643, 'name': 'Mount Gambier', 'cod': 200}
# 2156643
# Mount Gambier
# {'coord': {'lon': -78.15, 'lat': -10.07}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 291.44, 'feels_like': 288.54, 'temp_min': 291.44, 'temp_max': 291.44, 'pressure': 1014, 'humidity': 70, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 5.35, 'deg': 192}, 'clouds': {'all': 64}, 'dt': 1597697642, 'sys': {'country': 'PE', 'sunrise': 1597663367, 'sunset': 1597705837}, 'timezone': -18000, 'id': 3939168, 'name': 'Huarmey', 'cod': 200}
# 3939168
# Huarmey
# {'coord': {'lon': -8.33, 'lat': 40.16}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 294.82, 'feels_like': 295.99, 'temp_min': 294.82, 'temp_max': 294.82, 'pressure': 1016, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 291, 'gust': 3.58}, 'clouds': {'all': 22}, 'dt': 1597697643, 'sys': {'type': 3, 'id': 2001739, 'country': 'PT', 'sunrise': 1597643220, 'sunset': 1597692476}, 'timezone': 3600, 'id': 2738381, 'name': 'Lata', 'cod': 200}
# 2738381
# Lata
# {'coord': {'lon': 117.81, 'lat': 9.19}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 299.7, 'feels_like': 302.82, 'temp_min': 299.7, 'temp_max': 299.7, 'pressure': 1007, 'humidity': 80, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 2.88, 'deg': 241}, 'clouds': {'all': 100}, 'dt': 1597697643, 'sys': {'country': 'PH', 'sunrise': 1597701643, 'sunset': 1597746289}, 'timezone': 28800, 'id': 1684245, 'name': 'Tagusao', 'cod': 200}
# 1684245
# Tagusao
# {'coord': {'lon': 116.64, 'lat': 23.67}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 299.15, 'feels_like': 303.48, 'temp_min': 299.15, 'temp_max': 299.15, 'pressure': 1008, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 2, 'deg': 310}, 'clouds': {'all': 20}, 'dt': 1597697643, 'sys': {'type': 1, 'id': 9632, 'country': 'CN', 'sunrise': 1597701022, 'sunset': 1597747472}, 'timezone': 28800, 'id': 1815395, 'name': 'Chaozhou', 'cod': 200}
# 1815395
# Chaozhou
# {'coord': {'lon': 145.57, 'lat': 43.32}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 289.05, 'feels_like': 287.54, 'temp_min': 289.05, 'temp_max': 289.05, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.43, 'deg': 24}, 'clouds': {'all': 59}, 'dt': 1597697643, 'sys': {'country': 'JP', 'sunrise': 1597692378, 'sunset': 1597742231}, 'timezone': 32400, 'id': 2128975, 'name': 'Nemuro', 'cod': 200}
# 2128975
# Nemuro
# {'coord': {'lon': 5.78, 'lat': 59.92}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 293.15, 'feels_like': 294.45, 'temp_min': 292.04, 'temp_max': 294.26, 'pressure': 1010, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 98}, 'clouds': {'all': 50}, 'dt': 1597697644, 'sys': {'type': 3, 'id': 2010426, 'country': 'NO', 'sunrise': 1597636641, 'sunset': 1597692283}, 'timezone': 7200, 'id': 3133472, 'name': 'Hellvik', 'cod': 200}
# 3133472
# Hellvik
# {'coord': {'lon': 30.78, 'lat': 28.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 300.69, 'feels_like': 297.58, 'temp_min': 300.69, 'temp_max': 300.69, 'pressure': 1007, 'humidity': 51, 'sea_level': 1007, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 7.55, 'deg': 3}, 'clouds': {'all': 0}, 'dt': 1597697644, 'sys': {'country': 'EG', 'sunrise': 1597634864, 'sunset': 1597682062}, 'timezone': 7200, 'id': 352628, 'name': 'Maţāy', 'cod': 200}
# 352628
# Maţāy
# {'coord': {'lon': 25.74, 'lat': 35.01}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 298.71, 'feels_like': 295.58, 'temp_min': 298.71, 'temp_max': 298.71, 'pressure': 1009, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 4.92, 'deg': 90, 'gust': 7.6}, 'clouds': {'all': 0}, 'dt': 1597697645, 'sys': {'type': 3, 'id': 2017542, 'country': 'GR', 'sunrise': 1597635532, 'sunset': 1597683813}, 'timezone': 10800, 'id': 261814, 'name': 'Ierapetra', 'cod': 200}
# 261814
# Ierapetra
# {'coord': {'lon': 102.28, 'lat': 60.34}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 281.36, 'feels_like': 278.44, 'temp_min': 281.36, 'temp_max': 281.36, 'pressure': 1017, 'humidity': 69, 'sea_level': 1017, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 106}, 'clouds': {'all': 99}, 'dt': 1597697645, 'sys': {'country': 'RU', 'sunrise': 1597699876, 'sunset': 1597755509}, 'timezone': 25200, 'id': 2013727, 'name': 'Vanavara', 'cod': 200}
# 2013727
# Vanavara
# {'coord': {'lon': -7.17, 'lat': 62.16}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 283.15, 'feels_like': 282.15, 'temp_min': 283.15, 'temp_max': 283.15, 'pressure': 1013, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 270}, 'clouds': {'all': 1}, 'dt': 1597697645, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1597639112, 'sunset': 1597696027}, 'timezone': 3600, 'id': 2610343, 'name': 'Vestmanna', 'cod': 200}
# 2610343
# Vestmanna
# {'coord': {'lon': -81.27, 'lat': -4.58}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 291.72, 'feels_like': 287.57, 'temp_min': 291.72, 'temp_max': 291.72, 'pressure': 1011, 'humidity': 79, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 8.16, 'deg': 196}, 'clouds': {'all': 26}, 'dt': 1597697646, 'sys': {'country': 'PE', 'sunrise': 1597663804, 'sunset': 1597706898}, 'timezone': -18000, 'id': 3691582, 'name': 'Talara', 'cod': 200}
# 3691582
# Talara
# {'coord': {'lon': 18.35, 'lat': 68.86}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 282.15, 'feels_like': 272.6, 'temp_min': 282.15, 'temp_max': 282.15, 'pressure': 1011, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 12.3, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1597697646, 'sys': {'type': 1, 'id': 1619, 'country': 'NO', 'sunrise': 1597630078, 'sunset': 1597692814}, 'timezone': 7200, 'id': 3139765, 'name': 'Setermoen', 'cod': 200}
# 3139765
# Setermoen
# {'coord': {'lon': 115.25, 'lat': -2.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 295.37, 'feels_like': 299.37, 'temp_min': 295.37, 'temp_max': 295.37, 'pressure': 1009, 'humidity': 93, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 0.29, 'deg': 75}, 'clouds': {'all': 66}, 'dt': 1597697646, 'sys': {'country': 'ID', 'sunrise': 1597702910, 'sunset': 1597746250}, 'timezone': 28800, 'id': 1651461, 'name': 'Amuntai', 'cod': 200}
# 1651461
# Amuntai
# {'coord': {'lon': 139.9, 'lat': 69.3}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 276.46, 'feels_like': 273.29, 'temp_min': 276.46, 'temp_max': 276.46, 'pressure': 1015, 'humidity': 80, 'sea_level': 1015, 'grnd_level': 945}, 'visibility': 10000, 'wind': {'speed': 1.73, 'deg': 265}, 'clouds': {'all': 72}, 'dt': 1597697273, 'sys': {'country': 'RU', 'sunrise': 1597687213, 'sunset': 1597750118}, 'timezone': 36000, 'id': 2028164, 'name': 'Deputatsky', 'cod': 200}
# 2028164
# Deputatsky
# {'coord': {'lon': 25.97, 'lat': 70.98}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 281.15, 'feels_like': 276.44, 'temp_min': 281.15, 'temp_max': 281.15, 'pressure': 1005, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 260}, 'clouds': {'all': 75}, 'dt': 1597697646, 'sys': {'type': 1, 'id': 1638, 'country': 'NO', 'sunrise': 1597626740, 'sunset': 1597692494}, 'timezone': 7200, 'id': 779554, 'name': 'Honningsvåg', 'cod': 200}
# 779554
# Honningsvåg
# {'coord': {'lon': 114.98, 'lat': 27.12}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 299.74, 'feels_like': 303.6, 'temp_min': 299.74, 'temp_max': 299.74, 'pressure': 1008, 'humidity': 74, 'sea_level': 1008, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 0.88, 'deg': 25}, 'clouds': {'all': 0}, 'dt': 1597697647, 'sys': {'country': 'CN', 'sunrise': 1597701177, 'sunset': 1597748114}, 'timezone': 28800, 'id': 1806445, 'name': 'Ji’an', 'cod': 200}
# 1806445
# Ji’an
# {'coord': {'lon': 126.98, 'lat': 37.57}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 296.45, 'feels_like': 301.5, 'temp_min': 296.15, 'temp_max': 297.15, 'pressure': 1014, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 0.52, 'deg': 286}, 'clouds': {'all': 1}, 'dt': 1597697079, 'sys': {'type': 1, 'id': 8117, 'country': 'KR', 'sunrise': 1597697435, 'sunset': 1597746096}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}
# 1835848
# Seoul
# {'coord': {'lon': 23.04, 'lat': 69.01}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 280.41, 'feels_like': 276.52, 'temp_min': 280.41, 'temp_max': 280.41, 'pressure': 1009, 'humidity': 78, 'sea_level': 1009, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 3.59, 'deg': 245}, 'clouds': {'all': 100}, 'dt': 1597697647, 'sys': {'country': 'NO', 'sunrise': 1597628856, 'sunset': 1597691784}, 'timezone': 7200, 'id': 779330, 'name': 'Kautokeino', 'cod': 200}
# 779330
# Kautokeino
# {'coord': {'lon': 146.42, 'lat': 68.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 280.42, 'feels_like': 275.94, 'temp_min': 280.42, 'temp_max': 280.42, 'pressure': 1014, 'humidity': 75, 'sea_level': 1014, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.29, 'deg': 282}, 'clouds': {'all': 90}, 'dt': 1597697289, 'sys': {'country': 'RU', 'sunrise': 1597686103, 'sunset': 1597748098}, 'timezone': 39600, 'id': 2126785, 'name': 'Belaya Gora', 'cod': 200}
# 2126785
# Belaya Gora
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3e54e33ac048> in <module>
#       8         print(response['name'])
#       9
# ---> 10 print(response["sys"]["id"])
#      11 print(response["name"])
#
# KeyError: 'id'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
# Start with clean_df then use the .loc method to find where the drug regimen is Capomulin.
# capomulin_regimen = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin"]
# capomulin_regimen

# For the scatter use groupby [Mouse ID] and average it.
# vol_average = capomulin_regimen.groupby(["Mouse ID"]).mean()
# vol_average


# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
# plt.scatter((vol_average["Weight (g)"]), (vol_average["Tumor Volume (mm3)"]))
# plt.xlabel('Mouse Weight (g)')
# plt.ylabel('Average Tumor Volume (mm3)')
# plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
