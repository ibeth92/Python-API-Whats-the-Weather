# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_file = '../WeatherPy/output_data/cities.csv'

# Read Purchasing File and store into Pandas data frame
csv_df = pd.read_csv(city_file, encoding="ISO-8859-1")

# View Heatmap Data Frame
csv_df.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_5fb1b0c0_e28b_11ea_ac89_186590d2906d" ><thead>    <tr>        <th class="col_heading level0 col0" >City_ID</th>        <th class="col_heading level0 col1" >City</th>        <th class="col_heading level0 col2" >Lat</th>        <th class="col_heading level0 col3" >Lng</th>        <th class="col_heading level0 col4" >Max Temp</th>        <th class="col_heading level0 col5" >Humidity</th>        <th class="col_heading level0 col6" >Cloudiness</th>        <th class="col_heading level0 col7" >Wind Speed</th>        <th class="col_heading level0 col8" >Country</th>        <th class="col_heading level0 col9" >Date</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_5fb1b0c0_e28b_11ea_ac89_186590d2906drow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_5fb1b0c0_e28b_11ea_ac89_186590d2906drow0_col1" class="data row0 col1" >atherton</td>
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
# !jupyter nbextension enable --py --sys-prefix gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %%
gmaps.configure(api_key=g_key)
import gmaps.datasets

# %%
g_key
# Out:
# 'AIzaSyDPPCGqwluGaMMMCaoHk2uSDUaPuL8RFxg'

# %%
#locations = earthquake_df[['latitude', 'longitude']]
#weights = earthquake_df['magnitude']
#fig = gmaps.figure()
#fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
#fig

# %%
locations = csv_df[["Lat", "Lng"]]
Humidity = csv_df["Max Temp"]
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=Humidity)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Narrow down the DataFrame to find your ideal weather condition. 
# A max temperature lower than 80 degrees but higher than 70.
ideal_data_df = csv_df.loc[csv_df["Max Temp"] < 80]
ideal_data_df = ideal_data_df.loc[csv_df["Max Temp"] >70]
ideal_data_df = ideal_data_df.loc[csv_df["Wind Speed"] < 10]
ideal_data_df = ideal_data_df.loc[csv_df["Cloudiness"] == 0]
ideal_data_df
# Out:
#      City_ID             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 69        69         cururupu  -1.83  -44.87     75.43        85           0
# 131      131         marmaris  36.85   28.27     77.00        73           0
# 142      142            amapa   1.00  -52.00     72.32        96           0
# 255      255          jiuquan  39.74   98.52     78.89        18           0
# 293      293  fort-shevchenko  44.51   50.26     72.68        66           0
# 327      327   ramon castilla  -4.26  -69.96     77.00       100           0
# 334      334      paragominas  -2.97  -47.48     76.35        77           0
# 343      343            matay  28.42   30.78     70.97        74           0
# 379      379      maryborough -25.53  152.70     79.75        41           0
# 397      397            mendi  -6.18  143.65     72.14        49           0
# 423      423           baglan  36.13   68.71     75.78        30           0
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
ideal_data_df["Hotel Name"] =""

# %%
# Store into variable named hotel_df
# Add a "Hotel Name" column to the DataFrame
hotel_df = ideal_data_df.assign(Hotel = "")
hotel_df
# Out:
#      City_ID             City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 69        69         cururupu  -1.83  -44.87     75.43        85           0
# 131      131         marmaris  36.85   28.27     77.00        73           0
# 142      142            amapa   1.00  -52.00     72.32        96           0
# 255      255          jiuquan  39.74   98.52     78.89        18           0
# 293      293  fort-shevchenko  44.51   50.26     72.68        66           0
# 327      327   ramon castilla  -4.26  -69.96     77.00       100           0
# 334      334      paragominas  -2.97  -47.48     76.35        77           0
# 343      343            matay  28.42   30.78     70.97        74           0
# 379      379      maryborough -25.53  152.70     79.75        41           0
# 397      397            mendi  -6.18  143.65     72.14        49           0
# 423      423           baglan  36.13   68.71     75.78        30           0
# ...

# %%
# Set parameters to search for hotels with 5000 meters
# Hit the Google Places API for each city's coordinates
# Store the first Hotel result into the DataFrame
# Plot markers on top of the heatmap

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
