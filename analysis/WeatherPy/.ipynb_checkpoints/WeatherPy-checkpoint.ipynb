# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q=seattle&appid={weather_api_key}").json()
response["coord"]["lon"]
print(response)
# Out:
# {'coord': {'lon': -122.33, 'lat': 47.61}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 295.77, 'feels_like': 297.15, 'temp_min': 293.15, 'temp_max': 298.71, 'pressure': 1009, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 335, 'gust': 1.34}, 'clouds': {'all': 85}, 'dt': 1597893031, 'sys': {'type': 3, 'id': 2004026, 'country': 'US', 'sunrise': 1597842688, 'sunset': 1597893267}, 'timezone': -25200, 'id': 5809844, 'name': 'Seattle', 'cod': 200}

# %%
#EXAMPLE EXAMPLE
#responses = []
#set_counter = 0
#counter = 0

#for city in cities:
#    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
#    response = requests.get(url)
#    responses.append(response)
   
#    if set_counter == 50:
#        set_counter += 1
    
#    if counter == 40:
#        break
        
#print("Processing Record %s of Set %s | %s" % (counter, set_counter, city))

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
# Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

# Create endpoint URL with each city
    city_url = url + "&q=" + city
    
# Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

# Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities
    try:
# Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

# Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
# Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng,
                          "Max Temp" : city_max_temp, 
                          "Humidity": city_humidity,
                          "Cloudiness" : city_cloudiness,
                          "Wind Speed" : city_wind_speed,
                          "Country" :  city_country,
                          "Date": city_date})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | noyabrsk
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | eskisehir
# Processing Record 8 of Set 1 | suao
# City not found. Skipping...
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | matay
# Processing Record 11 of Set 1 | nakusp
# Processing Record 12 of Set 1 | palmer
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | axim
# Processing Record 21 of Set 1 | chumikan
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | honiara
# Processing Record 28 of Set 1 | grand gaube
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | montepulciano
# Processing Record 31 of Set 1 | nyaunglebin
# Processing Record 32 of Set 1 | cururupu
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record
# Processing Record 32 of Set 4 | cartagena
# Processing Record 33 of Set 4 | nanakuli
# Processing Record 34 of Set 4 | tres arroyos
# Processing Record 35 of Set 4 | belaya gora
# Processing Record 36 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 4 | catuday
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | murdochville
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 44 of Set 4 | kokopo
# Processing Record 45 of Set 4 | omsukchan
# Processing Record 46 of Set 4 | alice springs
# Processing Record 47 of Set 4 | mgandu
# Processing Record 48 of Set 4 | saint anthony
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 0 of Set 5 | bell ville
# Processing Record 1 of Set 5 | ravanusa
# Processing Record 2 of Set 5 | burnie
# Processing Record 3 of Set 5 | techiman
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | sesheke
# Processing Record 7 of Set 5 | asau
# Processing Record 8 of Set 5 | ferkessedougou
# Processing Record 9 of Set 5 | murray bridge
# Processing Record 10 of Set 5 | gamba
# Processing Record 11 of Set 5 | la libertad
# Processing Record 12 of Set 5 | victoria
# Processing Record 13 of Set 5 | noumea
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | san andres
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | kieta
# Processing Record 18 of Set 5 | walvis bay
# Processing Record 19 of Set 5 | canete
# Processing Record 20 of Set 5 | acarau
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | bitung
# Processing Record 23 of Set 5 | barra do garcas
# Processing Record 24 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 5 | camacupa
# Processing Record 26 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 5 | new sibonga
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | lebu
# Processing Record 30 of Set 5 | jumla
# Processing Record 31 of Set 5 | ballina
# Processing Record 32 of Set 5 | mahebourg
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | labuhan
# Processing Record 35 of Set 5 | pisco
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | taungdwingyi
# Processing Record 38 of Set 5 | chapais
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | richards bay
# Processing Record 41 of Set 5 | talnakh
# Processing Record 42 of Set 5 | port-gentil
# Processing Record 43 of Set 5 | fort nelson
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | orotukan
# Processing Record 46 of Set 5 | markova
# Processing Record 47 of Set 5 | minggang
# Processing Record 48 of Set 5 | dunedin
# Processing Record 49 of Set 5 | norman wells
# Processing Record 0 of Set 6 | dothan
# Processing Record 1 of Set 6 | thunder bay
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | livingston
# Processing Record 5 of Set 6 | coihaique
# Processing Record 6 of Set 6 | puerto ayora
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 9 of Set 6 | norden
# Processing Record 10 of Set 6 | bilma
# Processing Record 11 of Set 6 | manado
# Processing Record 12 of Set 6 | dudinka
# Processing Record 13 of Set 6 | kaya
# Processing Record 14 of Set 6 | roma
# Processing Record 15 of Set 6 | mecca
# Processing Record 16 of Set 6 | ingham
# Processing Record 17 of Set 6 | san cristobal
# Processing Record 18 of Set 6 | mugur-aksy
# Processing Record 19 of Set 6 | nemuro
# Processing Record 20 of Set 6 | vilyuysk
# Processing Record 21 of Set 6 | yatou
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 6 | gurupa
# Processing Record 25 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 6 | villarrica
# Processing Record 27 of Set 6 | san estanislao
# Processing Record 28 of Set 6 | gazanjyk
# Processing Record 29 of Set 6 | champerico
# Processing Record 30 of Set 6 | sitka
# Processing Record 31 of Set 6 | airai
# Processing Record 32 of Set 6 | parabel
# Processing Record 33 of Set 6 | rosario oeste
# Processing Record 34 of Set 6 | mogadishu
# Processing Record 35 of Set 6 | cap malheureux
# Processing Record 36 of Set 6 | kahului
# Processing Record 37 of Set 6 | brigham city
# Processing Record 38 of Set 6 | camacha
# Processing Record 39 of Set 6 | te anau
# Processing Record 40 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 6 | liverpool
# Processing Record 42 of Set 6 | sakakah
# Processing Record 43 of Set 6 | mehamn
# Processing Record 44 of Set 6 | bull savanna
# Processing Record 45 of Set 6 | henties bay
# Processing Record 46 of Set 6 | dikson
# Processing Record 47 of Set 6 | tambopata
# Processing Record 48 of Set 6 | yefimovskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | grindavik
# Processing Record 0 of Set 7 | saint-denis
# Processing Record 1 of Set 7 | mizdah
# Processing Record 2 of Set 7 | komsomolskiy
# Processing Record 3 of Set 7 | opuwo
# Processing Record 4 of Set 7 | sao miguel
# Processing Record 5 of Set 7 | plettenberg bay
# Processing Record 6 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | la ronge
# Processing Record 9 of Set 7 | santa fe
# Processing Record 10 of Set 7 | high level
# Processing Record 11 of Set 7 | severo-yeniseyskiy
# Processing Record 12 of Set 7 | maputo
# Processing Record 13 of Set 7 | maceio
# Processing Record 14 of Set 7 | sawakin
# Processing Record 15 of Set 7 | roches noires
# City not found. Skipping...
# Processing Record 16 of Set 7 | blackwater
# Processing Record 17 of Set 7 | bani
# Processing Record 18 of Set 7 | askino
# Processing Record 19 of Set 7 | huicungo
# Processing Record 20 of Set 7 | el dorado
# Processing Record 21 of Set 7 | ilulissat
# Processing Record 22 of Set 7 | georgiyevka
# Processing Record 42 of Set 8 | acajutla
# Processing Record 43 of Set 8 | nouadhibou
# Processing Record 44 of Set 8 | marmora
# Processing Record 45 of Set 8 | maldonado
# Processing Record 46 of Set 8 | pangnirtung
# Processing Record 47 of Set 8 | geraldton
# Processing Record 48 of Set 8 | vestmannaeyjar
# Processing Record 49 of Set 8 | gat
# Processing Record 0 of Set 9 | abeche
# Processing Record 1 of Set 9 | farmington
# Processing Record 2 of Set 9 | asfi
# Processing Record 3 of Set 9 | astara
# Processing Record 4 of Set 9 | amot
# Processing Record 5 of Set 9 | takhtamygda
# Processing Record 6 of Set 9 | bad doberan
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | karratha
# Processing Record 9 of Set 9 | biak
# Processing Record 10 of Set 9 | pochinki
# Processing Record 11 of Set 9 | nicoya
# Processing Record 12 of Set 9 | neryungri
# Processing Record 13 of Set 9 | christchurch
# Processing Record 14 of Set 9 | boden
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | pathein
# Processing Record 17 of Set 9 | dalvik
# Processing Record 18 of Set 9 | guaitarilla
# Processing Record 19 of Set 9 | paslek
# Processing Record 20 of Set 9 | hambantota
# Processing Record 21 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 22 of Set 9 | itoman
# Processing Record 23 of Set 9 | dingle
# Processing Record 24 of Set 9 | boke
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | kiruna
# Processing Record 27 of Set 9 | sunrise manor
# Processing Record 28 of Set 9 | rio gallegos
# Processing Record 29 of Set 9 | kenora
# Processing Record 30 of Set 9 | udachnyy
# Processing Record 31 of Set 9 | tessalit
# Processing Record 32 of Set 9 | khatra
# Processing Record 33 of Set 9 | melun
# Processing Record 34 of Set 9 | santa paula
# Processing Record 35 of Set 9 | san policarpo
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | awbari
# Processing Record 38 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 9 | antalaha
# Processing Record 40 of Set 9 | dawlatabad
# Processing Record 41 of Set 9 | klaksvik
# Processing Record 42 of Set 9 | sayyan
# Processing Record 43 of Set 9 | vardo
# Processing Record 44 of Set 9 | saint george
# Processing Record 45 of Set 9 | todos santos
# Processing Record 46 of Set 9 | baoding
# Processing Record 47 of Set 9 | maniitsoq
# Processing Record 48 of Set 9 | zhuozhou
# City not found. Skipping...
# Processing Record 49 of Set 9 | mahemdavad
# Processing Record 0 of Set 10 | makhachkala
# Processing Record 1 of Set 10 | nanchong
# Processing Record 2 of Set 10 | adre
# Processing Record 3 of Set 10 | bethel
# Processing Record 4 of Set 10 | barrancas
# Processing Record 5 of Set 10 | turukhansk
# Processing Record 6 of Set 10 | touros
# Processing Record 7 of Set 10 | deputatskiy
# Processing Record 8 of Set 10 | novonukutskiy
# Processing Record 9 of Set 10 | meulaboh
# Processing Record 10 of Set 10 | pekan
# Processing Record 11 of Set 10 | san patricio
# Processing Record 12 of Set 10 | nelson bay
# Processing Record 13 of Set 10 | fortuna
# Processing Record 14 of Set 10 | bodden town
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 10 | hasaki
# Processing Record 18 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 10 | jasper
# Processing Record 20 of Set 10 | mattawa
# Processing Record 21 of Set 10 | mandera
# Processing Record 22 of Set 10 | nizhniy odes
# Processing Record 23 of Set 10 | longyearbyen
# Processing Record 24 of Set 10 | nouna
# Processing Record 25 of Set 10 | mocuba
# Processing Record 26 of Set 10 | sanming
# Processing Record 27 of Set 10 | skerries
# Processing Record 28 of Set 10 | baghdad
# Processing Record 29 of Set 10 | candido mendes
# Processing Record 30 of Set 10 | leningradskiy
# Processing Record 31 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 10 | skibbereen
# Processing Record 33 of Set 10 | petauke
# Processing Record 34 of Set 10 | de-kastri
# Processing Record 35 of Set 10 | kudahuvadhoo
# Processing Record 36 of Set 10 | kaeo
# Processing Record 37 of Set 10 | bosaso
# Processing Record 38 of Set 10 | taoudenni
# Processing Record 39 of Set 10 | port hardy
# Processing Record 40 of Set 10 | olafsvik
# Processing Record 41 of Set 10 | nyurba
# Processing Record 42 of Set 10 | rorvik
# Processing Record 43 of Set 10 | zelenogradsk
# Processing Record 44 of Set 10 | mundo nuevo
# Processing Record 45 of Set 10 | burica
# City not found. Skipping...
# Processing Record 46 of Set 10 | banda aceh
# Processing Record 47 of Set 10 | kungurtug
# Processing Record 48 of Set 10 | moindou
# Processing Record 49 of Set 10 | porto seguro
# Processing Record 0 of Set 11 | jian
# Processing Record 1 of Set 11 | thinadhoo
# Processing Record 2 of Set 11 | fasa
# Processing Record 3 of Set 11 | kununurra
# Processing Record 4 of Set 11 | cayenne
# Processing Record 5 of Set 11 | ginir
# Processing Record 6 of Set 11 | znamenskoye
# Processing Record 7 of Set 11 | port lincoln
# Processing Record 8 of Set 11 | teguise
# Processing Record 9 of Set 11 | yerbogachen
# Processing Record 10 of Set 11 | alyangula
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | uyemskiy
# Processing Record 14 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 11 | maturin
# Processing Record 16 of Set 11 | magomeni
# Processing Record 17 of Set 11 | galle
# Processing Record 18 of Set 11 | vidim
# Processing Record 19 of Set 11 | karaton
# Processing Record 20 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 11 | saint-leu
# Processing Record 22 of Set 11 | clarence town
# Processing Record 23 of Set 11 | husavik
# Processing Record 24 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 11 | coquimbo
# Processing Record 26 of Set 11 | smirnykh
# Processing Record 27 of Set 11 | warmbad
# Processing Record 28 of Set 11 | carballo
# Processing Record 29 of Set 11 | coachella
# Processing Record 30 of Set 11 | bang mun nak
# Processing Record 31 of Set 11 | boa vista
# Processing Record 32 of Set 11 | lisala
# Processing Record 33 of Set 11 | port moresby
# Processing Record 34 of Set 11 | northam
# Processing Record 35 of Set 11 | stara synyava
# Processing Record 36 of Set 11 | ekhabi
# Processing Record 37 of Set 11 | bambous virieux
# Processing Record 38 of Set 11 | ossora
# Processing Record 39 of Set 11 | merauke
# Processing Record 40 of Set 11 | gornyy
# Processing Record 41 of Set 11 | garissa
# Processing Record 42 of Set 11 | kuryk
# Processing Record 43 of Set 11 | lianran
# Processing Record 44 of Set 11 | mont-de-marsan
# Processing Record 45 of Set 11 | malanje
# Processing Record 46 of Set 11 | bundaberg
# Processing Record 47 of Set 11 | tautira
# Processing Record 48 of Set 11 | samarai
# Processing Record 49 of Set 11 | asosa
# Processing Record 0 of Set 12 | howard springs
# Processing Record 1 of Set 12 | terrace
# Processing Record 2 of Set 12 | sakhnovshchyna
# Processing Record 3 of Set 12 | stornoway
# Processing Record 4 of Set 12 | saint marys
# Processing Record 5 of Set 12 | viransehir
# Processing Record 6 of Set 12 | wellington
# Processing Record 7 of Set 12 | sopo
# Processing Record 8 of Set 12 | quartucciu
# Processing Record 9 of Set 12 | ambilobe
# Processing Record 10 of Set 12 | chara
# Processing Record 11 of Set 12 | mahanje
# Processing Record 12 of Set 12 | dashitou
# Processing Record 13 of Set 12 | arlit
# Processing Record 14 of Set 12 | oistins
# Processing Record 15 of Set 12 | shimanovsk
# Processing Record 16 of Set 12 | kathu
# Processing Record 17 of Set 12 | lianzhou
# Processing Record 18 of Set 12 | svirstroy
# Processing Record 19 of Set 12 | calvinia
# Processing Record 20 of Set 12 | manta
# Processing Record 21 of Set 12 | bubaque
# Processing Record 22 of Set 12 | teya
# Processing Record 23 of Set 12 | garwa
# Processing Record 24 of Set 12 | ostrovnoy
# Processing Record 25 of Set 12 | cairns
# Processing Record 26 of Set 12 | belyy yar
# Processing Record 27 of Set 12 | phalodi
# Processing Record 28 of Set 12 | rexburg
# Processing Record 29 of Set 12 | chor
# Processing Record 30 of Set 12 | aykhal
# Processing Record 31 of Set 12 | kautokeino
# Processing Record 32 of Set 12 | sisimiut
# Processing Record 33 of Set 12 | santa maria
# Processing Record 34 of Set 12 | margate
# Processing Record 35 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 12 | trinitapoli
# Processing Record 38 of Set 12 | nerchinskiy zavod
# Processing Record 39 of Set 12 | mali
# Processing Record 40 of Set 12 | auki
# Processing Record 41 of Set 12 | adeje
# Processing Record 42 of Set 12 | muros
# Processing Record 43 of Set 12 | sistranda
# Processing Record 44 of Set 12 | tongchuan
# Processing Record 45 of Set 12 | gobabis
# Processing Record 46 of Set 12 | vredendal
# Processing Record 47 of Set 12 | westport
# Processing Record 48 of Set 12 | sibu
# Processing Record 49 of Set 12 | tateyama
# Processing Record 0 of Set 13 | benicarlo
# Processing Record 1 of Set 13 | moree
# Processing Record 2 of Set 13 | kayes
# Processing Record 3 of Set 13 | puksoozero
# Processing Record 4 of Set 13 | yamnytsya
# Processing Record 5 of Set 13 | port hedland
# Processing Record 6 of Set 13 | saint john
# Processing Record 7 of Set 13 | dubbo
# Processing Record 8 of Set 13 | qasigiannguit
# Processing Record 9 of Set 13 | lompoc
# Processing Record 10 of Set 13 | eyl
# Processing Record 11 of Set 13 | yanji
# Processing Record 12 of Set 13 | haverfordwest
# Processing Record 13 of Set 13 | buraydah
# Processing Record 14 of Set 13 | qui nhon
# Processing Record 15 of Set 13 | maragogi
# Processing Record 16 of Set 13 | tiznit

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
output_data_file = "output_data/cities.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    noyabrsk  63.20   75.45     59.13        79           1       12.03
# 1  butaritari   3.07  172.79     83.52        76          97       10.58
# 2      hobart -42.88  147.33     55.40        55          20       19.46
# 3      narsaq  60.92  -46.05     50.00        66          15        4.70
# 4       kapaa  22.08 -159.32     84.20        66          40       13.87
#
#   Country        Date
# 0      RU  1597893370
# 1      KI  1597893371
# 2      AU  1597893199
# 3      GL  1597893371
# 4      US  1597893371

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Get the indices of cities that have humidity over 100%.
# Extract relevant fields from the data frame
# Export the City_Data into a csv
humidity_check = city_data_df.loc[(city_data_df["Humidity"] > 100)]
humidity_check.count()
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_data_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    noyabrsk  63.20   75.45     59.13        79           1       12.03
# 1  butaritari   3.07  172.79     83.52        76          97       10.58
# 2      hobart -42.88  147.33     55.40        55          20       19.46
# 3      narsaq  60.92  -46.05     50.00        66          15        4.70
# 4       kapaa  22.08 -159.32     84.20        66          40       13.87
#
#   Country        Date
# 0      RU  1597893370
# 1      KI  1597893371
# 2      AU  1597893199
# 3      GL  1597893371
# 4      US  1597893371

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. temperature
#TO DO: Add "Latitude vs. Max Temperature (08/18/20)"
plt.scatter((city_data_df["Lat"]), (city_data_df["Max Temp"]))
plt.title("City Latitude vs. Max Temperature (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('plot_1')
plt.show()

# %%
# WRITE UP: This code is anlyzing the max temperatures across the latitudes of our different locations from the city data and displaying it in a scatter plot.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. humidity
#TO DO: Add "Latitude vs. Humidity (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Humidity"]))
plt.title("City Latitude vs. Humidity (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('plot_2')
plt.show()

# %%
# WRITE UP: This code is anlyzing the humidity across the latitudes of our different locations from the city data and displaying it in a scatter plot.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. cloudiness
#TO DO: Add "Latitude vs. Cloudiness (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
plt.title("City Latitude vs. Cloudiness (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('plot_3')
plt.show()

# %%
# WRITE UP: This code is anlyzing the cloudiness across the latitudes of our different locations from the city data and displaying it in a scatter plot.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. cloudiness
#TO DO: Add "Latitude vs. Wind Speed (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
plt.title("City Latitude vs. Wind Speed (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('plot_4')
plt.show()

# %%
# WRITE UP: This code is anlyzing the wind speed across the latitudes of our different locations from the city data and displaying it in a scatter plot.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# linear Regression
city_data_df

(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Max Temp"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Max Temp"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Max Temperature (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('plot_5')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Humidity"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Humidity"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Humidity (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('plot_6')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Cloudiness (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('plot_7')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.title("City Latitude vs. Wind Speed (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('plot_8')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Max Temp"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Max Temp"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Max Temperature (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('plot_9')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Max Temp"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Max Temp"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Max Temperature (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('plot_10')
plt.show()

# %%
# WRITE UP: This code is anlyzing the humidity across the latitudes of our different locations from the city data and displaying it in the northern and southern hemispheres. 
# The scatter plots are showing liner regressions for each hemisphere which makes sense as to why they plot opposite of one another. 
# The max temperature is higher the closer your latitude is to 0, or the equator and the opposite is aslo demonstrated.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Humidity"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Humidity"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Humidity (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('plot_11')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Humidity"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Humidity"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Humidity (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.savefig('plot_12')
plt.show()

# %%
# WRITE UP: This code is anlyzing the max temperature across the latitudes of our different locations from the city data and displaying it in the northern and southern hemispheres. 
# The scatter plots are showing liner regressions for each hemisphere which makes sense as to why they plot opposite of one another. 
# The humidity is slightly higher the closer your latitude is to 0, or the equator and the opposite is aslo demonstrated.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Cloudiness"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Cloudiness"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Cloudiness (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('plot_13')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Cloudiness"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Cloudiness"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.title("City Latitude vs. Cloudiness (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.savefig('plot_14')
plt.show()

# %%
# WRITE UP: This code is anlyzing the cloudiness percentage across the latitudes of our different locations from the city data and displaying it in the northern and southern hemispheres. 
# The scatter plots are showing liner regressions for each hemisphere which makes sense as to why they plot opposite of one another. 
# The cloudiness is slightly higher the closer your latitude is to 0, or the equator and the opposite is aslo demonstrated.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Wind Speed"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Wind Speed"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.title("City Latitude vs. Wind Speed (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('plot_15')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
# Start with clean_df then use the .loc method to find where the northern and souther
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Wind Speed"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Wind Speed"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.title("City Latitude vs. Wind Speed (08/18/20)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('plot_16')
plt.show()

# %%
# WRITE UP: This code is anlyzing the wind speed  across the latitudes of our different locations from the city data and displaying it in the northern and southern hemispheres. 
# The scatter plots are showing liner regressions for each hemisphere which makes sense as to why they plot opposite of one another. 
# The wind speed is slightly lower the closer your latitude is to 0, or the equator which is not as strong of a liner regression correlation as the previous examples.
