# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
response = requests.get(f"http://api.openweathermap.org/data/2.5/weather?q=seattle&appid={weather_api_key}").json()
response["coord"]["lon"]
print(response)
# Out:
# {'coord': {'lon': -122.33, 'lat': 47.61}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 294.77, 'feels_like': 292.66, 'temp_min': 293.15, 'temp_max': 295.93, 'pressure': 1021, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 190}, 'clouds': {'all': 75}, 'dt': 1597774960, 'sys': {'type': 1, 'id': 3417, 'country': 'US', 'sunrise': 1597756207, 'sunset': 1597806975}, 'timezone': -25200, 'id': 5809844, 'name': 'Seattle', 'cod': 200}

# %%
#EXAMPLE EXAMPLE
#responses = []
#set_counter = 0
#counter = 0

#for city in cities:
#    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
#    response = requests.get(url)
#    responses.append(response)
   
#    if set_counter == 50:
#        set_counter += 1
    
#    if counter == 40:
#        break
        
#print("Processing Record %s of Set %s | %s" % (counter, set_counter, city))

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
# Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

# Create endpoint URL with each city
    city_url = url + "&q=" + city
    
# Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

# Add 1 to the record count
    record_count += 1

# Run an API request for each of the cities
    try:
# Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

# Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        
# Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng,
                          "Max Temp" : city_max_temp, 
                          "Humidity": city_humidity,
                          "Cloudiness" : city_cloudiness,
                          "Wind Speed" : city_wind_speed,
                          "Country" :  city_country,
                          "Date": city_date})

# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | tatarastii de sus
# City not found. Skipping...
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | kemijarvi
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | chuncheng
# Processing Record 10 of Set 1 | tabas
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | santa maria
# Processing Record 13 of Set 1 | auki
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | belyy yar
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | verkh-usugli
# Processing Record 18 of Set 1 | cedral
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | yanam
# Processing Record 21 of Set 1 | praia da vitoria
# Processing Record 22 of Set 1 | fortuna
# Processing Record 23 of Set 1 | samarai
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | vestmannaeyjar
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | atar
# Processing Record 31 of Set 1 | san patricio
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | kumluca
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | verkhnevilyuysk
# Processing Record 36 of Set 1 | alofi
# Processing Record 37 of Set 1 | marsh harbour
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | puerto baquerizo moreno
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | nara
# Processing Record 46 of Set 1 | deputatskiy
# Processing Record 47 of Set 1 | half moon bay
# Processing Record 48 of Set 1 | kindu
# Processing Record 49 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | isangel
# Processing Record 0 of Set 2 | ardatov
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | huarmey
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | cozumel
# Processing Record 12 of Set 2 | tokat
# Processing Record 13 of Set 2 | batticaloa
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | sialkot
# Processing Record 17 of Set 2 | portobelo
# Processing Record 18 of Set 2 | acari
# Processing Record 19 of Set 2 | sembe
# Processing Record 20 of Set 2 | mayumba
# Processing Record 21 of Set 2 | pocoes
# Processing Record 22 of Set 2 | mikhaylovka
# Processing Record 23 of Set 2 | avera
# Processing Record 24 of Set 2 | debre tabor
# Processing Record 25 of Set 2 | miramar
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | homer
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | narsaq
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | olinda
# Processing Record 34 of Set 2 | fare
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 2 | san
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | chicama
# Processing Record 44 of Set 2 | desaguadero
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | qandahar
# City not found. Skipping...
# Processing Record 47 of Set 2 | suoyarvi
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | barra
# Processing Record 0 of Set 3 | veraval
# Processing Record 1 of Set 3 | aswan
# Processing Record 2 of Set 3 | tuatapere
# Processing Record 3 of Set 3 | pacific grove
# Processing Record 4 of Set 3 | baherden
# Processing Record 5 of Set 3 | paamiut
# Processing Record 6 of Set 3 | arlit
# Processing Record 7 of Set 3 | xiongzhou
# Processing Record 8 of Set 3 | matagami
# Processing Record 9 of Set 3 | merauke
# Processing Record 10 of Set 3 | lermontovka
# Processing Record 11 of Set 3 | shchuchye
# City not found. Skipping...
# Processing Record 12 of Set 3 | milkovo
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 15 of Set 3 | ballina
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | same
# Processing Record 18 of Set 3 | lovozero
# Processing Record 19 of Set 3 | moerai
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | alyangula
# Processing Record 22 of Set 3 | mae sai
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | port-gentil
# Processing Record 26 of Set 3 | oistins
# Processing Record 27 of Set 3 | hays
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 3 | tshikapa
# Processing Record 32 of Set 3 | lagos
# Processing Record 33 of Set 3 | vostok
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | fez
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | kahului
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | nizwa
# Processing Record 40 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 41 of Set 3 | icod de los vinos
# Processing Record 42 of Set 3 | agropoli
# Processing Record 43 of Set 3 | benoy
# Processing Record 44 of Set 3 | hojai
# Processing Record 45 of Set 3 | akyab
# Processing Record 46 of Set 3 | kodiak
# Processing Record 47 of Set 3 | kedougou
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | phangnga
# Processing Record 0 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 4 | nemuro
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | tingi
# Processing Record 6 of Set 4 | haines junction
# Processing Record 7 of Set 4 | palana
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | hermanus
# Processing Record 10 of Set 4 | marivan
# Processing Record 11 of Set 4 | portland
# Processing Record 12 of Set 4 | port hedland
# Processing Record 13 of Set 4 | padang
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | mount gambier
# Processing Record 16 of Set 4 | sao jose da coroa grande
# Processing Record 17 of Set 4 | lorengau
# Processing Record 18 of Set 4 | zhuji
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | oktyabrskiy
# Processing Record 21 of Set 4 | putyatino
# Processing Record 22 of Set 4 | buraydah
# Processing Record 23 of Set 4 | fairbanks
# Processing Record 24 of Set 4 | itoman
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | cascais
# Processing Record 28 of Set 4 | bubaque
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | burica
# City not found. Skipping...
# Processing Record 31 of Set 4 | nishihara
# Processing Record 32 of Set 4 | salalah
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | acajutla
# Processing Record 35 of Set 4 | ketchikan
# Processing Record 36 of Set 4 | buchanan
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | east london
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | turbat
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | kapaa
# Processing Record 45 of Set 4 | jiayuguan
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | gbarnga
# Processing Record 48 of Set 4 | west point
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 0 of Set 5 | carnarvon
# Processing Record 1 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 5 | agadez
# Processing Record 3 of Set 5 | radenci
# Processing Record 4 of Set 5 | anadyr
# Processing Record 5 of Set 5 | lata
# Processing Record 6 of Set 5 | oxapampa
# Processing Record 7 of Set 5 | barrow
# Processing Record 8 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 5 | tuktoyaktuk
# Processing Record 10 of Set 5 | augusto correa
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | provideniya
# Processing Record 13 of Set 5 | eureka
# Processing Record 14 of Set 5 | port blair
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | te anau
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | nanortalik
# Processing Record 19 of Set 5 | aksu
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | sitka
# Processing Record 22 of Set 5 | kisangani
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | talakan
# Processing Record 25 of Set 5 | poum
# Processing Record 26 of Set 5 | new norfolk
# Processing Record 27 of Set 5 | kungurtug
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | novikovo
# Processing Record 30 of Set 5 | ajdabiya
# Processing Record 31 of Set 5 | gamba
# Processing Record 32 of Set 5 | berlevag
# Processing Record 33 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 5 | male
# Processing Record 35 of Set 5 | hasaki
# Processing Record 36 of Set 5 | pouebo
# Processing Record 37 of Set 5 | shihezi
# Processing Record 38 of Set 5 | ruteng
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | sao paulo de olivenca
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | palora
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | bairiki
# Processing Record 46 of Set 5 | caravelas
# Processing Record 47 of Set 5 | sovetskiy
# Processing Record 48 of Set 5 | batemans bay
# Processing Record 49 of Set 5 | hami
# Processing Record 0 of Set 6 | matamba
# Processing Record 1 of Set 6 | campbell river
# Processing Record 2 of Set 6 | puerto leguizamo
# Processing Record 3 of Set 6 | lavrentiya
# Processing Record 4 of Set 6 | pasighat
# Processing Record 5 of Set 6 | luang prabang
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | bereda
# Processing Record 8 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 9 of Set 6 | kwekwe
# Processing Record 10 of Set 6 | namatanai
# Processing Record 11 of Set 6 | williams lake
# Processing Record 12 of Set 6 | sale
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | san policarpo
# Processing Record 15 of Set 6 | ust-koksa
# Processing Record 16 of Set 6 | stornoway
# Processing Record 17 of Set 6 | oranjestad
# Processing Record 18 of Set 6 | khani
# Processing Record 19 of Set 6 | tabuk
# Processing Record 20 of Set 6 | okha
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | dvinskoy
# Processing Record 24 of Set 6 | pisco
# Processing Record 25 of Set 6 | tiznit
# Processing Record 26 of Set 6 | januaria
# Processing Record 27 of Set 6 | beloha
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 6 | kulu
# Processing Record 30 of Set 6 | elektrougli
# Processing Record 31 of Set 6 | gazli
# Processing Record 32 of Set 6 | araouane
# Processing Record 33 of Set 6 | vyshneve
# Processing Record 34 of Set 6 | champerico
# Processing Record 35 of Set 6 | saint-pierre
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | sibolga
# Processing Record 38 of Set 6 | belmonte
# Processing Record 39 of Set 6 | polyarnyy
# Processing Record 40 of Set 6 | ostrovnoy
# Processing Record 41 of Set 6 | chatsu
# City not found. Skipping...
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | huanren
# Processing Record 44 of Set 6 | gazojak
# Processing Record 45 of Set 6 | nortelandia
# Processing Record 46 of Set 6 | labuhan
# Processing Record 47 of Set 6 | klyuchi
# Processing Record 48 of Set 6 | mountain home
# Processing Record 49 of Set 6 | necochea
# Processing Record 0 of Set 7 | uruguaiana
# Processing Record 1 of Set 7 | ola
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | belfast
# Processing Record 4 of Set 7 | aberdeen
# Processing Record 5 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 7 | nisia floresta
# Processing Record 8 of Set 7 | tasiilaq
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 11 of Set 7 | mangrol
# Processing Record 12 of Set 7 | domoni
# Processing Record 13 of Set 7 | panipat
# Processing Record 14 of Set 7 | kjopsvik
# Processing Record 15 of Set 7 | oni
# Processing Record 16 of Set 7 | celestun
# Processing Record 17 of Set 7 | cabra
# Processing Record 18 of Set 7 | disna
# Processing Record 19 of Set 7 | riyadh
# Processing Record 20 of Set 7 | basco
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | bilibino
# Processing Record 23 of Set 7 | carai
# Processing Record 24 of Set 7 | kentville
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | le port
# Processing Record 27 of Set 7 | cayenne
# Processing Record 28 of Set 7 | brae
# Processing Record 29 of Set 7 | piacabucu
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | sola
# Processing Record 32 of Set 7 | cherskiy
# Processing Record 33 of Set 7 | chernyshevskiy
# Processing Record 34 of Set 7 | yeppoon
# Processing Record 35 of Set 7 | manta
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 7 | presidencia roque saenz pena
# Processing Record 39 of Set 7 | dwarka
# Processing Record 40 of Set 7 | talcahuano
# Processing Record 41 of Set 7 | itaituba
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | san cristobal
# Processing Record 44 of Set 7 | el alto
# Processing Record 45 of Set 7 | minas
# Processing Record 46 of Set 7 | bara
# Processing Record 47 of Set 7 | maneadero
# Processing Record 48 of Set 7 | mwandiga
# Processing Record 49 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 0 of Set 8 | sisimiut
# Processing Record 1 of Set 8 | altamirano
# Processing Record 2 of Set 8 | karratha
# Processing Record 3 of Set 8 | mulchen
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | port lincoln
# Processing Record 6 of Set 8 | takoradi
# Processing Record 7 of Set 8 | coahuayana
# Processing Record 8 of Set 8 | siderno
# Processing Record 9 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 8 | quatre cocos
# Processing Record 11 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 8 | souris
# Processing Record 13 of Set 8 | pita
# Processing Record 14 of Set 8 | carauari
# Processing Record 15 of Set 8 | sobolevo
# Processing Record 16 of Set 8 | skjervoy
# Processing Record 17 of Set 8 | yazman
# Processing Record 18 of Set 8 | coolum beach
# Processing Record 19 of Set 8 | san andres
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | bam
# Processing Record 22 of Set 8 | kralendijk
# Processing Record 23 of Set 8 | constitucion
# Processing Record 24 of Set 8 | duz
# City not found. Skipping...
# Processing Record 25 of Set 8 | aklavik
# Processing Record 26 of Set 8 | bud
# Processing Record 27 of Set 8 | kapit
# Processing Record 28 of Set 8 | yashkul
# Processing Record 29 of Set 8 | greenville
# Processing Record 30 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 8 | gigmoto
# Processing Record 32 of Set 8 | mantua
# Processing Record 33 of Set 8 | jacareacanga
# Processing Record 34 of Set 8 | lompoc
# Processing Record 35 of Set 8 | donskoye
# Processing Record 36 of Set 8 | muzhi
# Processing Record 37 of Set 8 | belaya gora
# Processing Record 38 of Set 8 | santa cruz cabralia
# Processing Record 39 of Set 8 | itacare
# Processing Record 40 of Set 8 | springbok
# Processing Record 41 of Set 8 | felanitx
# Processing Record 42 of Set 8 | almaty
# Processing Record 43 of Set 8 | harper
# Processing Record 44 of Set 8 | nicoya
# Processing Record 45 of Set 8 | haapiti
# Processing Record 46 of Set 8 | toppenish
# Processing Record 47 of Set 8 | vineland
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | punta cardon
# Processing Record 0 of Set 9 | seoul
# Processing Record 1 of Set 9 | zhanaozen
# Processing Record 2 of Set 9 | san lorenzo
# Processing Record 3 of Set 9 | lincoln
# Processing Record 4 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 9 | cabedelo
# Processing Record 6 of Set 9 | waingapu
# Processing Record 7 of Set 9 | bestobe
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | komsomolskiy
# Processing Record 10 of Set 9 | oksfjord
# Processing Record 11 of Set 9 | kamaishi
# Processing Record 12 of Set 9 | galesong
# Processing Record 13 of Set 9 | kloulklubed
# Processing Record 14 of Set 9 | byron bay
# Processing Record 15 of Set 9 | nelson bay
# Processing Record 16 of Set 9 | virginia beach
# Processing Record 17 of Set 9 | belogradcik
# City not found. Skipping...
# Processing Record 18 of Set 9 | bamako
# Processing Record 19 of Set 9 | raga
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | bardsir
# Processing Record 22 of Set 9 | puerto lopez
# Processing Record 23 of Set 9 | aromashevo
# Processing Record 24 of Set 9 | carutapera
# Processing Record 25 of Set 9 | dordrecht
# Processing Record 26 of Set 9 | thibodaux
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | goderich
# Processing Record 29 of Set 9 | santo angelo
# Processing Record 30 of Set 9 | porto novo
# Processing Record 31 of Set 9 | makungu
# Processing Record 32 of Set 9 | sabha
# Processing Record 33 of Set 9 | tselinnoye
# Processing Record 34 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 9 | invermere
# Processing Record 36 of Set 9 | hanna
# Processing Record 37 of Set 9 | saint anthony
# Processing Record 38 of Set 9 | pontianak
# Processing Record 39 of Set 9 | tiarei
# Processing Record 40 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 9 | balkanabat
# Processing Record 42 of Set 9 | coihaique
# Processing Record 43 of Set 9 | urengoy
# Processing Record 44 of Set 9 | poltavka
# Processing Record 45 of Set 9 | kendari
# Processing Record 46 of Set 9 | tura
# Processing Record 47 of Set 9 | denau
# City not found. Skipping...
# Processing Record 48 of Set 9 | harrison
# Processing Record 49 of Set 9 | linchuan
# City not found. Skipping...
# Processing Record 0 of Set 10 | chokurdakh
# Processing Record 1 of Set 10 | wanaka
# Processing Record 2 of Set 10 | great falls
# Processing Record 3 of Set 10 | muros
# Processing Record 4 of Set 10 | nouakchott
# Processing Record 5 of Set 10 | richards bay
# Processing Record 6 of Set 10 | suhl
# Processing Record 7 of Set 10 | matara
# Processing Record 8 of Set 10 | altamura
# Processing Record 9 of Set 10 | takhtamygda
# Processing Record 10 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | lapa
# Processing Record 12 of Set 10 | dukhovshchina
# Processing Record 13 of Set 10 | bongandanga
# Processing Record 14 of Set 10 | taoudenni
# Processing Record 15 of Set 10 | sulangan
# Processing Record 16 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 10 | thinadhoo
# Processing Record 18 of Set 10 | bose
# Processing Record 19 of Set 10 | ochakiv
# Processing Record 20 of Set 10 | sibu
# Processing Record 21 of Set 10 | buala
# Processing Record 22 of Set 10 | henties bay
# Processing Record 23 of Set 10 | gushikawa
# Processing Record 24 of Set 10 | espanola
# Processing Record 25 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 26 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 27 of Set 10 | whyalla
# Processing Record 28 of Set 10 | murdochville
# Processing Record 29 of Set 10 | dalbandin
# Processing Record 30 of Set 10 | taywarah
# Processing Record 31 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 10 | samsun
# Processing Record 33 of Set 10 | ratnagiri
# Processing Record 34 of Set 10 | talara
# Processing Record 35 of Set 10 | kedrovyy
# Processing Record 36 of Set 10 | nambucca heads
# Processing Record 37 of Set 10 | rio gallegos
# Processing Record 38 of Set 10 | narwar
# Processing Record 39 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 10 | dingle
# Processing Record 41 of Set 10 | alcaniz
# Processing Record 42 of Set 10 | kazachinskoye
# Processing Record 43 of Set 10 | san joaquin
# Processing Record 44 of Set 10 | cambridge
# Processing Record 45 of Set 10 | marzuq
# Processing Record 46 of Set 10 | staryy nadym
# Processing Record 47 of Set 10 | iquitos
# Processing Record 48 of Set 10 | providencia
# Processing Record 49 of Set 10 | miyako
# Processing Record 0 of Set 11 | tazovskiy
# Processing Record 1 of Set 11 | suntar
# Processing Record 2 of Set 11 | cubuk
# Processing Record 3 of Set 11 | hatillo
# Processing Record 4 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 11 | jaque
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | longyan
# Processing Record 8 of Set 11 | tignere
# Processing Record 9 of Set 11 | charkhi dadri
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | sistranda
# Processing Record 12 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | zhigansk
# Processing Record 15 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 11 | santa vitoria do palmar
# Processing Record 17 of Set 11 | tanda
# Processing Record 18 of Set 11 | birjand
# Processing Record 19 of Set 11 | batken
# Processing Record 20 of Set 11 | strelka
# Processing Record 21 of Set 11 | lesosibirsk
# Processing Record 22 of Set 11 | baykit
# Processing Record 23 of Set 11 | palmer
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 11 | tabou
# Processing Record 27 of Set 11 | bradley
# Processing Record 28 of Set 11 | paraiso
# Processing Record 29 of Set 11 | cockburn town
# Processing Record 30 of Set 11 | graaff-reinet
# Processing Record 31 of Set 11 | olga
# Processing Record 32 of Set 11 | inhambane
# Processing Record 33 of Set 11 | catia la mar
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | magallanes
# Processing Record 36 of Set 11 | taloqan
# Processing Record 37 of Set 11 | tonekabon
# Processing Record 38 of Set 11 | urucui
# Processing Record 39 of Set 11 | mount pleasant
# Processing Record 40 of Set 11 | kankon
# Processing Record 41 of Set 11 | abha
# Processing Record 42 of Set 11 | puerto guzman
# Processing Record 43 of Set 11 | cidreira
# Processing Record 44 of Set 11 | tuy hoa
# Processing Record 45 of Set 11 | emirdag
# Processing Record 46 of Set 11 | lazaro cardenas
# Processing Record 47 of Set 11 | pangnirtung
# Processing Record 48 of Set 11 | rayagada
# Processing Record 49 of Set 11 | la romana
# Processing Record 0 of Set 12 | uaua
# Processing Record 1 of Set 12 | todos santos
# Processing Record 2 of Set 12 | concordia
# Processing Record 3 of Set 12 | prince rupert
# Processing Record 4 of Set 12 | zalantun
# Processing Record 5 of Set 12 | manokwari
# Processing Record 6 of Set 12 | pombia
# Processing Record 7 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 12 | metro
# Processing Record 9 of Set 12 | ancud
# Processing Record 10 of Set 12 | shingu
# Processing Record 11 of Set 12 | college
# Processing Record 12 of Set 12 | yian
# City not found. Skipping...
# Processing Record 13 of Set 12 | saint-francois
# Processing Record 14 of Set 12 | waidhofen
# Processing Record 15 of Set 12 | matay
# Processing Record 16 of Set 12 | fort morgan
# Processing Record 17 of Set 12 | marawi
# Processing Record 18 of Set 12 | deer lake
# Processing Record 19 of Set 12 | chuy
# Processing Record 20 of Set 12 | igdir
# Processing Record 21 of Set 12 | mahon
# Processing Record 22 of Set 12 | iskateley
# Processing Record 23 of Set 12 | zory
# Processing Record 24 of Set 12 | abancay
# Processing Record 25 of Set 12 | nexo
# Processing Record 26 of Set 12 | lyngseidet
# Processing Record 27 of Set 12 | vila velha
# Processing Record 28 of Set 12 | gijon
# Processing Record 29 of Set 12 | calamar
# Processing Record 30 of Set 12 | hamilton
# Processing Record 31 of Set 12 | manado
# Processing Record 32 of Set 12 | klaksvik
# Processing Record 33 of Set 12 | kabare
# Processing Record 34 of Set 12 | maniitsoq
# Processing Record 35 of Set 12 | kavieng
# Processing Record 36 of Set 12 | altay
# Processing Record 37 of Set 12 | jaisalmer
# Processing Record 38 of Set 12 | peniche
# Processing Record 39 of Set 12 | cap-aux-meules
# Processing Record 40 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 41 of Set 12 | kudahuvadhoo
# Processing Record 42 of Set 12 | onalaska
# Processing Record 43 of Set 12 | almeirim
# Processing Record 44 of Set 12 | skibbereen
# Processing Record 45 of Set 12 | yerofey pavlovich
# Processing Record 46 of Set 12 | umzimvubu
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          536
# Lat           536
# Lng           536
# Max Temp      536
# Humidity      536
# Cloudiness    536
# Wind Speed    536
# Country       536
# Date          536
# dtype: int64

# %%
output_data_file = "output_data/cities.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         vaini -21.20 -175.20     73.40        94          90       11.41
# 1  punta arenas -53.15  -70.92     37.40        47          40       17.22
# 2       ushuaia -54.80  -68.30     35.60        64          75       12.75
# 3         tiksi  71.69  128.87     38.93        91         100       12.48
# 4       rikitea -23.12 -134.97     71.76        81           2       12.82
#
#   Country        Date
# 0      TO  1597775160
# 1      CL  1597775337
# 2      AR  1597775273
# 3      RU  1597775046
# 4      PF  1597775143

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Get the indices of cities that have humidity over 100%.
# Extract relevant fields from the data frame
# Export the City_Data into a csv
humidity_check = city_data_df.loc[(city_data_df["Humidity"] > 100)]
humidity_check.count()
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
city_data_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         vaini -21.20 -175.20     73.40        94          90       11.41
# 1  punta arenas -53.15  -70.92     37.40        47          40       17.22
# 2       ushuaia -54.80  -68.30     35.60        64          75       12.75
# 3         tiksi  71.69  128.87     38.93        91         100       12.48
# 4       rikitea -23.12 -134.97     71.76        81           2       12.82
#
#   Country        Date
# 0      TO  1597775160
# 1      CL  1597775337
# 2      AR  1597775273
# 3      RU  1597775046
# 4      PF  1597775143

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. temperature
#TO DO: Add "Latitude vs. Max Temperature (08/18/20)"
plt.scatter((city_data_df["Lat"]), (city_data_df["Max Temp"]))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. humidity
#TO DO: Add "Latitude vs. Humidity (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Humidity"]))
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. cloudiness
#TO DO: Add "Latitude vs. Cloudiness (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Use city_data_df to crate scatter plot
# Generate a scatter plot of latitude vs. cloudiness
#TO DO: Add "Latitude vs. Wind Speed (08/18/20)"

plt.scatter((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# linear Regression
city_data_df

(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Max Temp"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Max Temp"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Humidity"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Humidity"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Cloudiness"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
regress_values = (city_data_df["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((city_data_df["Lat"]), (city_data_df["Wind Speed"]))
plt.plot((city_data_df["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Max Temp"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Max Temp"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Max Temp"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Max Temp"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Humidity"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Humidity"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Humidity"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Humidity"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Cloudiness"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Cloudiness"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Cloudiness"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Cloudiness"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[city_data_df["Lat"] >= 0]
northern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((northern_hemisphere["Lat"]), (northern_hemisphere["Wind Speed"]))
regress_values = (northern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((northern_hemisphere["Lat"]), (northern_hemisphere["Wind Speed"]))
plt.plot((northern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
# Start with clean_df then use the .loc method to find where the northern and souther
southern_hemisphere = city_data_df.loc[city_data_df["Lat"] < 0]
southern_hemisphere

(slope, intercept, rvalue, pvalue, stderr) = linregress((southern_hemisphere["Lat"]), (southern_hemisphere["Wind Speed"]))
regress_values = (southern_hemisphere["Lat"]) * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter((southern_hemisphere["Lat"]), (southern_hemisphere["Wind Speed"]))
plt.plot((southern_hemisphere["Lat"]),regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
